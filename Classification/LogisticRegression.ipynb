# %% [markdown]
# # Logistic Regression
# This programm runs logistic regression in order to predict wether stock is a good option to buy. Stock is classified as 'Buy' if it'll beat SP500 and ROI is above 2%.

# %% [markdown]
# ### 1. Imports

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## First attempt (fewer data)

# %% [markdown]
# ### 2. Load the data

# %%
data = pd.read_csv('stocks_data.csv')
data.describe(include='all')
# Out:
#           Unnamed: 0 Ticker          Year         Month      MA Ratio  \
# count   14854.000000  14854  14854.000000  14854.000000  14854.000000
# unique           NaN    393           NaN           NaN           NaN
# top              NaN    AWK           NaN           NaN           NaN
# freq             NaN     55           NaN           NaN           NaN
# mean     7426.500000    NaN   2020.669113      6.223240      1.004148
# std      4288.124784    NaN      1.428016      3.520757      0.046473
# min         0.000000    NaN   2018.000000      1.000000      0.580721
# 25%      3713.250000    NaN   2019.000000      3.000000      0.977766
# 50%      7426.500000    NaN   2021.000000      6.000000      1.005360
# 75%     11139.750000    NaN   2022.000000      9.000000      1.031953
# max     14853.000000    NaN   2023.000000     12.000000      1.335656
#
#                  Buy        Result           ROE  Insider Ownership Growth  \
# count   14854.000000  14854.000000  14854.000000              14854.000000
# unique           NaN           NaN           NaN                       NaN
# top              NaN           NaN           NaN                       NaN
# freq             NaN           NaN           NaN                       NaN
# mean        0.415848      1.032817     39.494365                  0.015486
# std         0.492884      0.149260    181.839873                  0.269863
# min         0.000000      0.259712   -613.743387                 -0.633527
# 25%         0.000000      0.944153     10.160854                 -0.001350
# 50%         0.000000      1.028547     19.251991                  0.000000
# 75%         1.000000      1.113949     31.949569                  0.008000
# max         1.000000      3.142137  11300.330487                 17.759731
#
#         Institutional Ownership Growth  Forecast EPS Growth  \
# count                     14854.000000         14854.000000
# unique                             NaN                  NaN
# top                                NaN                  NaN
# freq                               NaN                  NaN
# mean                          0.026708             0.057775
# std                           0.230675             2.136724
# min                          -0.714136            -0.992366
# 25%                          -0.023114            -0.184264
# 50%                          -0.000648            -0.039062
# 75%                           0.033653             0.086957
# max                          14.203540           133.000000
#
#         Avg 2Q EPS Growth  Avg 2Q EPS Surprise  YoY EPS Growth  \
# count        14854.000000         14854.000000    14854.000000
# unique                NaN                  NaN             NaN
# top                   NaN                  NaN             NaN
# freq                  NaN                  NaN             NaN
# mean             0.181477            13.755183        0.369529
# std              2.111809            46.751483        3.637998
# min            -45.050000           -65.625000       -0.961538
# 25%             -0.040838             2.015000        0.017606
# 50%              0.045662             6.055000        0.130688
# 75%              0.154182            13.135000        0.275148
# max             78.553797          1493.215000      192.000000
#
#         Sector Performance  Market Performance  Benchmark SP500 Performance
# count         14854.000000        14854.000000                 14854.000000
# unique                 NaN                 NaN                          NaN
# top                    NaN                 NaN                          NaN
# freq                   NaN                 NaN                          NaN
# mean              1.488003            1.438443                     1.029219
# std               8.164589            7.038394                     0.077491
# min             -44.900728          -22.795349                     0.769903
# 25%              -3.453784           -3.160007                     0.983314
# 50%               1.496227            2.069271                     1.043101
# 75%               6.429508            5.507430                     1.080728
# max              31.971220           21.644623                     1.243323

# %% [markdown]
# ### 3. Clean the data
# Let's remove outliers.

# %%
for column in ['ROE', 'Insider Ownership Growth', 'Institutional Ownership Growth', 'Forecast EPS Growth', 'Avg 2Q EPS Growth', 'YoY EPS Growth']:
    upper_bound = data[column].quantile(0.999)
    data = data[(data[column] <= upper_bound)]
q = data['Avg 2Q EPS Growth'].quantile(0.001)
data = data[(data['Avg 2Q EPS Growth'] >= q)]
data.describe(include='all')
# Out:
#           Unnamed: 0 Ticker          Year         Month      MA Ratio  \
# count   14757.000000  14757  14757.000000  14757.000000  14757.000000
# unique           NaN    391           NaN           NaN           NaN
# top              NaN    IQV           NaN           NaN           NaN
# freq             NaN     55           NaN           NaN           NaN
# mean     7431.564546    NaN   2020.665447      6.222877      1.004135
# std      4285.343004    NaN      1.428264      3.521282      0.046414
# min         0.000000    NaN   2018.000000      1.000000      0.580721
# 25%      3726.000000    NaN   2019.000000      3.000000      0.977791
# 50%      7430.000000    NaN   2021.000000      6.000000      1.005388
# 75%     11144.000000    NaN   2022.000000      9.000000      1.031914
# max     14853.000000    NaN   2023.000000     12.000000      1.335656
#
#                  Buy        Result           ROE  Insider Ownership Growth  \
# count   14757.000000  14757.000000  14757.000000              14757.000000
# unique           NaN           NaN           NaN                       NaN
# top              NaN           NaN           NaN                       NaN
# freq             NaN           NaN           NaN                       NaN
# mean        0.415735      1.032886     35.930619                  0.009596
# std         0.492865      0.149125     99.720733                  0.072866
# min         0.000000      0.259712   -613.743387                 -0.633527
# 25%         0.000000      0.944257     10.176162                 -0.001361
# 50%         0.000000      1.028536     19.293997                  0.000000
# 75%         1.000000      1.113877     31.949569                  0.007968
# max         1.000000      3.142137   1723.426083                  1.636364
#
#         Institutional Ownership Growth  Forecast EPS Growth  \
# count                     14757.000000         14757.000000
# unique                             NaN                  NaN
# top                                NaN                  NaN
# freq                               NaN                  NaN
# mean                          0.021883             0.011317
# std                           0.133643             0.519399
# min                          -0.714136            -0.992366
# 25%                          -0.023167            -0.182927
# 50%                          -0.000699            -0.038835
# 75%                           0.033287             0.086705
# max                           1.596845             8.514706
#
#         Avg 2Q EPS Growth  Avg 2Q EPS Surprise  YoY EPS Growth  \
# count        14757.000000         14757.000000    14757.000000
# unique                NaN                  NaN             NaN
# top                   NaN                  NaN             NaN
# freq                  NaN                  NaN             NaN
# mean             0.145736            13.522146        0.272787
# std              0.806091            45.365794        1.069267
# min             -3.489011           -65.625000       -0.961538
# 25%             -0.040646             1.995000        0.018152
# 50%              0.045532             6.010000        0.130396
# 75%              0.152364            13.080000        0.274611
# max             27.731828          1493.215000       31.500000
#
#         Sector Performance  Market Performance  Benchmark SP500 Performance
# count         14757.000000        14757.000000                 14757.000000
# unique                 NaN                 NaN                          NaN
# top                    NaN                 NaN                          NaN
# freq                   NaN                 NaN                          NaN
# mean              1.486683            1.441679                     1.029255
# std               8.159292            7.043774                     0.077495
# min             -44.900728          -22.795349                     0.769903
# 25%              -3.453784           -3.160007                     0.983314
# 50%               1.496227            2.069271                     1.043101
# 75%               6.429508            5.507430                     1.080728
# max              31.971220           21.644623                     1.243323

# %% [markdown]
# ### 4. Split the data for train and test, standarise the data

# %%
data = data.reset_index(drop=True)
train_data = data[data['Year'] <= 2022]
test_data = data[data['Year'] > 2022]
x_train = train_data.drop(['Year', 'Buy', 'Month', 'Ticker', 'Result', 'Benchmark SP500 Performance', data.columns[0]], axis=1)
y_train = train_data['Buy']
x_test = test_data.drop(['Year', 'Buy', 'Month', 'Ticker', 'Result', 'Benchmark SP500 Performance', data.columns[0]], axis=1)
y_test = test_data['Buy']

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)

x_test = scaler.transform(x_test)

# %% [markdown]
# ### 5. Train the model

# %%
model = LogisticRegression(max_iter = 10000, class_weight={0: 100, 1: 100})
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %% [markdown]
# ### 6. Evaluation

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
precision = precision_score(y_test, y_pred)
print(f'Precision: {precision}')

conf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion Matrix:')
print(conf_matrix)

class_report = classification_report(y_test, y_pred)
print('Classification Report:')
print(class_report)
# Out:
# Accuracy: 0.6596664607782582
# Precision: 0.28
# Confusion Matrix:
# [[1061   18]
#  [ 533    7]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      0.98      0.79      1079
#            1       0.28      0.01      0.02       540
#
#     accuracy                           0.66      1619
#    macro avg       0.47      0.50      0.41      1619
# weighted avg       0.54      0.66      0.54      1619

# %%
test_results = test_data.copy()
test_results['Predicted_Buy'] = y_pred

predicted_stocks_to_buy = test_results[test_results['Predicted_Buy'] == 1]
predicted_stocks_avg_return = predicted_stocks_to_buy['Result'].mean()

avg_stock_return = test_results['Result'].mean()

best_stocks = test_results[test_results['Buy'] == 1]
avg_best_stocks_return = best_stocks['Result'].mean()

sp500_return = predicted_stocks_to_buy['Benchmark SP500 Performance'].mean()

print("Benchmarks: ")
print(f"Average stock return (whole test sample): {avg_stock_return:.3f}")
print(f"'Buy' stocks average return: {avg_best_stocks_return:.3f}")
print(f"SP500 return: {sp500_return:.3f}")

print(f"\nModel's predicted stock average return: {predicted_stocks_avg_return:.3f}")
# Out:
# Benchmarks:
# Average stock return (whole test sample): 1.032
# 'Buy' stocks average return: 1.176
# SP500 return: 1.057
#
# Model's predicted stock average return: 1.043

# %% [markdown]
# ### 7. Conclusion
# The results achieved by the model leave much to be desired. Both the low precision and poorer performance compared to the S&P 500 suggest that logistic regression may not be suitable for building an investment strategy in this case. To investigate this further, more data is needed as well as the application of feature engineering. For example, by modifying the class weights and giving 20% more weight to class 0, the model achieves an ROI of 13%, which is a very good result compared to the S&P 500 (5%). However, the recall is extremely low, below 1%, so there is a high probability that this is just a fluke.

# %% [markdown]
# ## Second attempt (more data)
# In this attempt, data with a broader date range (from around 2008 for most companies) was used. This range includes several recession periods, providing greater diversity for the model to learn from. Additionally, columns containing information on the companies' Return on Assets and Return on Invested Capital were added.

# %% [markdown]
# ### 1. Read & preprocess the data

# %%
data = pd.read_csv('stocks_data4.csv')
data.describe(include='all')
# Out:
#           Unnamed: 0 Ticker          Year         Month         Price  \
# count   61517.000000  61517  61517.000000  61517.000000  61517.000000
# unique           NaN    417           NaN           NaN           NaN
# top              NaN    CPB           NaN           NaN           NaN
# freq             NaN    225           NaN           NaN           NaN
# mean    30758.000000    NaN   2015.561064      6.475576     86.090852
# std     17758.572592    NaN      5.130421      3.448068    145.204509
# min         0.000000    NaN   2005.000000      1.000000      0.170000
# 25%     15379.000000    NaN   2012.000000      3.000000     26.350000
# 50%     30758.000000    NaN   2016.000000      6.000000     49.240000
# 75%     46137.000000    NaN   2020.000000      9.000000     95.340000
# max     61516.000000    NaN   2024.000000     12.000000   3810.000000
#
#             MA Ratio           Buy        Result           ROE           ROA  \
# count   61517.000000  61517.000000  61517.000000  61517.000000  61517.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean        1.005282      0.454102      1.035127      0.262087      0.089610
# std         0.043844      0.497893      0.139926      8.540118      1.104599
# min         0.580721      0.000000      0.110349   -347.693570     -1.369770
# 25%         0.982233      0.000000      0.955759      0.095910      0.037540
# 50%         1.006824      0.000000      1.035871      0.166400      0.070180
# 75%         1.029836      1.000000      1.113424      0.266340      0.113230
# max         1.443446      1.000000      3.538378    509.372300    157.982210
#
#                  ROI  Insider Ownership Growth  \
# count   61517.000000              61517.000000
# unique           NaN                       NaN
# top              NaN                       NaN
# freq             NaN                       NaN
# mean        0.150720                  0.031192
# std         1.285496                  0.891108
# min       -15.336400                 -0.994779
# 25%         0.065280                 -0.003494
# 50%         0.114670                  0.000000
# 75%         0.186960                  0.008696
# max       181.327650                 76.000000
#
#         Institutional Ownership Growth  Forecast EPS Growth  \
# count                     61517.000000         61517.000000
# unique                             NaN                  NaN
# top                                NaN                  NaN
# freq                               NaN                  NaN
# mean                          0.025757             0.090401
# std                           0.250149             1.732801
# min                          -0.930676            -0.992366
# 25%                          -0.020228            -0.156716
# 50%                           0.000790            -0.016129
# 75%                           0.027434             0.110000
# max                          14.203540           133.000000
#
#         Avg 2Q EPS Growth  Avg 2Q EPS Surprise  YoY EPS Growth  \
# count        61517.000000         61517.000000    6.151700e+04
# unique                NaN                  NaN             NaN
# top                   NaN                  NaN             NaN
# freq                  NaN                  NaN             NaN
# mean             0.149241            11.124411    3.969275e+12
# std              1.515826            52.925722    4.301144e+14
# min            -58.668103           -93.235000   -1.000000e+00
# 25%             -0.036162             1.270000    1.214575e-02
# 50%              0.047591             4.740000    1.157895e-01
# 75%              0.157784            10.680000    2.425068e-01
# max             78.553797          3750.995000    5.764608e+16
#
#         Sector Performance  Market Performance  Benchmark SP500 Performance
# count         61517.000000        61517.000000                 61517.000000
# unique                 NaN                 NaN                          NaN
# top                    NaN                 NaN                          NaN
# freq                   NaN                 NaN                          NaN
# mean              1.641091            1.603703                     1.023901
# std               7.192112            6.071008                     0.072566
# min             -49.501466          -24.778692                     0.690014
# 25%              -2.055089           -1.243019                     0.989798
# 50%               2.177343            2.256661                     1.034544
# 75%               5.800866            5.367850                     1.066909
# max              43.727138           21.644623                     1.265488

# %%
for column in ['ROE', 'Insider Ownership Growth', 'Institutional Ownership Growth', 'Forecast EPS Growth', 'Avg 2Q EPS Growth', 'YoY EPS Growth']:
    upper_bound = data[column].quantile(0.999)
    data = data[(data[column] <= upper_bound)]
q = data['Avg 2Q EPS Growth'].quantile(0.001)
data = data[(data['Avg 2Q EPS Growth'] >= q)]
data.describe(include='all')
# Out:
#           Unnamed: 0 Ticker          Year         Month         Price  \
# count   61087.000000  61087  61087.000000  61087.000000  61087.000000
# unique           NaN    417           NaN           NaN           NaN
# top              NaN    SHW           NaN           NaN           NaN
# freq             NaN    225           NaN           NaN           NaN
# mean    30760.834187    NaN   2015.569221      6.478662     86.040855
# std     17750.016433    NaN      5.121289      3.449648    144.358576
# min         0.000000    NaN   2005.000000      1.000000      0.170000
# 25%     15398.500000    NaN   2012.000000      3.000000     26.390000
# 50%     30760.000000    NaN   2016.000000      6.000000     49.290000
# 75%     46143.500000    NaN   2020.000000      9.000000     95.410000
# max     61516.000000    NaN   2024.000000     12.000000   3810.000000
#
#             MA Ratio           Buy        Result           ROE           ROA  \
# count   61087.000000  61087.000000  61087.000000  61087.000000  61087.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean        1.005279      0.453894      1.035114      0.111004      0.082006
# std         0.043759      0.497874      0.139492      4.354249      0.065388
# min         0.580721      0.000000      0.110349   -347.693570     -1.369770
# 25%         0.982252      0.000000      0.955893      0.096130      0.037730
# 50%         1.006816      0.000000      1.035912      0.166670      0.070250
# 75%         1.029818      1.000000      1.113338      0.266075      0.113290
# max         1.443446      1.000000      3.538378     19.528570      1.313780
#
#                  ROI  Insider Ownership Growth  \
# count   61087.000000              61087.000000
# unique           NaN                       NaN
# top              NaN                       NaN
# freq             NaN                       NaN
# mean        0.141937                  0.011203
# std         0.227534                  0.160279
# min       -15.336400                 -0.994779
# 25%         0.065425                 -0.003509
# 50%         0.114810                  0.000000
# 75%         0.186910                  0.008621
# max        23.687470                  4.750000
#
#         Institutional Ownership Growth  Forecast EPS Growth  \
# count                     61087.000000         61087.000000
# unique                             NaN                  NaN
# top                                NaN                  NaN
# freq                               NaN                  NaN
# mean                          0.020213             0.048165
# std                           0.158886             0.661588
# min                          -0.930676            -0.992366
# 25%                          -0.020261            -0.156250
# 50%                           0.000723            -0.016129
# 75%                           0.027216             0.108752
# max                           3.115815            16.888889
#
#         Avg 2Q EPS Growth  Avg 2Q EPS Surprise  YoY EPS Growth  \
# count        61087.000000         61087.000000    61087.000000
# unique                NaN                  NaN             NaN
# top                   NaN                  NaN             NaN
# freq                  NaN                  NaN             NaN
# mean             0.135944            10.844773        0.204320
# std              0.638213            45.682348        0.708250
# min             -7.247826           -93.235000       -1.000000
# 25%             -0.035667             1.275000        0.012584
# 50%              0.047619             4.730000        0.115741
# 75%              0.157197            10.642500        0.241803
# max             16.014706          2768.315000       23.071429
#
#         Sector Performance  Market Performance  Benchmark SP500 Performance
# count         61087.000000        61087.000000                 61087.000000
# unique                 NaN                 NaN                          NaN
# top                    NaN                 NaN                          NaN
# freq                   NaN                 NaN                          NaN
# mean              1.642579            1.606065                     1.023948
# std               7.179243            6.067306                     0.072557
# min             -49.501466          -24.778692                     0.690014
# 25%              -2.055089           -1.243019                     0.989798
# 50%               2.177343            2.256661                     1.034544
# 75%               5.800866            5.367850                     1.066909
# max              43.727138           21.644623                     1.265488

# %% [markdown]
# ### 2. Split the data and train the model

# %%
cut_off_year = 2019

data = data.reset_index(drop=True)
train_data = data[(data['Year'] < cut_off_year) & ((data['Year'] != cut_off_year - 1) | (data['Month'] < 9))]
test_data = data[data['Year'] >= cut_off_year]
x_train = train_data.drop(['Year', 'Buy', 'Month', 'Ticker', 
                           'Result', 'Benchmark SP500 Performance', 
                           'Price', data.columns[0]], axis=1)
y_train = train_data['Buy']
x_test = test_data.drop(['Year', 'Buy', 'Month', 
                         'Ticker', 'Result', 'Benchmark SP500 Performance', 
                         'Price', data.columns[0]], axis=1)
y_test = test_data['Buy']

print(f"Amount of train data: {len(train_data)}")
print(f"Amount of test data: {len(test_data)}")

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)

x_test = scaler.transform(x_test)
# Out:
# Amount of train data: 39907
# Amount of test data: 19700

# %%
model = LogisticRegression(max_iter = 10000, class_weight={0: 130, 1: 100})
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %% [markdown]
# ### 3. Evaluate the model

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
precision = precision_score(y_test, y_pred)
print(f'Precision: {precision}')

conf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion Matrix:')
print(conf_matrix)

class_report = classification_report(y_test, y_pred)
print('Classification Report:')
print(class_report)
# Out:
# Accuracy: 0.596243654822335
# Precision: 0.5211864406779662
# Confusion Matrix:
# [[11623   113]
#  [ 7841   123]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.60      0.99      0.75     11736
#            1       0.52      0.02      0.03      7964
#
#     accuracy                           0.60     19700
#    macro avg       0.56      0.50      0.39     19700
# weighted avg       0.57      0.60      0.46     19700

# %%
test_results = test_data.copy()
test_results['Predicted_Buy'] = y_pred

predicted_stocks_to_buy = test_results[test_results['Predicted_Buy'] == 1]
predicted_stocks_avg_return = predicted_stocks_to_buy['Result'].mean()

avg_stock_return = test_results['Result'].mean()

best_stocks = test_results[test_results['Buy'] == 1]
avg_best_stocks_return = best_stocks['Result'].mean()

sp500_return = predicted_stocks_to_buy['Benchmark SP500 Performance'].mean()

print("Benchmarks: ")
print(f"Average stock return (whole test sample): {avg_stock_return:.3f}")
print(f"'Buy' stocks average return: {avg_best_stocks_return:.3f}")
print(f"SP500 return: {sp500_return:.3f}")

print(f"\nModel's predicted stock average return: {predicted_stocks_avg_return:.3f}")
# Out:
# Benchmarks:
# Average stock return (whole test sample): 1.034
# 'Buy' stocks average return: 1.160
# SP500 return: 1.051
#
# Model's predicted stock average return: 1.097

# %% [markdown]
# ### 4. Conclusions
# The model performs significantly better after being retrained on a larger dataset. Despite a modest accuracy of 52%, the model achieved an average ROI of 9.7% per 'Buy' signal. This improvement underscores the positive impact of increasing the dataset size on the model's accuracy and predictive capabilities. Such a result suggests that the model can be used to build a profitable investment strategy, but it also requires other elements, such as risk management and a precise definition of entry and exit strategies.

# %% [markdown]
# ### 5. Example strategy - backtest
# In this simple example strategy, a stock is purchased for up to 20% of the portfolio value if, in the new month, it is classified as 'Buy' and is not currently in the portfolio. A stock is sold in three cases:
# - if in the new month the stock is no longer classified as 'Buy',
# - if a stop loss occurs, meaning that in the new month the stocks' price drops by more than 5%,
# - at the end of the backtest, i.e., in May 2024, all stocks in the portfolio are sold at the last available price.

# %%
available_cash = 1000000
portfolio_worth = 1000000
current_buys = {}

backtest_data = test_results.copy()
backtest_data = backtest_data.sort_values(by=['Year', 'Month'])

def sell_stock(ticker, price):
    prev_price = current_buys[ticker]['price']
    amount = current_buys[ticker]['shares']

    global portfolio_worth, available_cash
    portfolio_worth -= prev_price * amount
    portfolio_worth += price * amount
    available_cash += price * amount

for index, row in backtest_data.iterrows():
    ticker = row['Ticker']
    prediction = row['Predicted_Buy']
    price = row['Price']

    if prediction == True:
        if ticker not in current_buys:
            allowed_spend = int(portfolio_worth / 5)
            
            if allowed_spend > available_cash:
                allowed_spend = available_cash

            if allowed_spend < portfolio_worth / 50:
                continue
                
            amount = int(allowed_spend / price)
            available_cash -= amount * price
            
            current_buys[ticker] = {'price': price, 'shares': amount, 'last_price': price}
            print(f"Added {ticker} to current_buys for {row['Year']}-{row['Month']} with price {price}")
        else:
            if price < current_buys[ticker]['price'] * 0.95: # Stop loss
                prev_price = current_buys[ticker]['price']
                
                sell_stock(ticker, price)
                del current_buys[ticker]
                
                print(f"Removed {ticker} from current_buys for {row['Year']}-{row['Month']} with price {price}; prev price: {prev_price}")
                print(f"New net worth: {portfolio_worth}")
            else:
                current_buys[ticker]['last_price'] = price
            
    else:
        if ticker in current_buys:
            prev_price = current_buys[ticker]['price']

            sell_stock(ticker, price)            
            del current_buys[ticker]
            
            print(f"Removed {ticker} from current_buys for {row['Year']}-{row['Month']} with price {price}; prev price: {prev_price}")
            print(f"New net worth: {portfolio_worth}")

for ticker in current_buys:
    sell_stock(ticker, current_buys[ticker]['last_price'])
    
    print(f"Removed {ticker} from current_buys")
    
print(portfolio_worth)
# Out:
# Added BBWI to current_buys for 2019-1 with price 18.72
# Added BG to current_buys for 2019-1 with price 44.69
# Added CAG to current_buys for 2019-1 with price 17.39
# Added EOG to current_buys for 2019-1 with price 71.04
# Added IDXX to current_buys for 2019-1 with price 182.46
# Removed CAG from current_buys for 2019-2 with price 17.62; prev price: 17.39
# New net worth: 1002645.0
# Removed EOG from current_buys for 2019-2 with price 77.68; prev price: 71.04
# New net worth: 1021336.6000000001
# Added CNC to current_buys for 2019-3 with price 61.34
# Added DPZ to current_buys for 2019-3 with price 236.41
# Removed CNC from current_buys for 2019-4 with price 54.16; prev price: 61.34
# New net worth: 997427.2000000002
# Removed DPZ from current_buys for 2019-4 with price 235.82; prev price: 236.41
# New net worth: 996917.4400000002
# Added MNST to current_buys for 2019-4 with price 26.64
# Added INTU to current_buys for 2019-5 with price 235.62
# Removed MNST from current_buys for 2019-5 with price 28.97; prev price: 26.64
# New net worth: 1014355.1600000001
# Added PSX to current_buys for 2019-5 with price 73.05
# Removed BG from current_buys for 2019-6 with price 46.55; prev price: 44.69
# New net worth: 1022678.6600000001
# Added DVN to current_buys for 2019-6 with price 19.18
# Removed IDXX from current_buys for 2019-6 with price 245.59; prev price: 182.46
# New net worth: 1091869.1400000001
# Added NVDA to current_buys for 2019-6 with price 3.33
# Removed PSX from current_buys for 2019-6 with price 66.07; prev price: 73.05
# New net worth: 1072485.6800000002
# Added VLO to current_buys for 2019-6 with price 57.2
# Added BG to current_buys for 2019-7 with price 47.99
# Removed DVN from current_buys for 2019-7 with price 21.81; prev price: 19.18
# New net worth: 1100529.37
# Removed NVDA from current_buys for 2019-7 with price 4.13; prev price: 3.33
# New net worth: 1152990.9700000002
# Removed VLO from current_buys for 2019-7 with price 66.93; prev price: 57.2
# New net worth: 1189468.7400000002
# Added AAL to current_buys for 2019-8 with price 29.54
# Added ALGN to current_buys for 2019-8 with price 202.35
# Added CTRA to current_buys for 2019-8 with price 14.82
# Added EA to current_buys for 2019-8 with price 92.52
# Removed AAL from current_buys for 2019-9 with price 26.33; prev price: 29.54
# New net worth: 1163618.6100000003
# Removed ALGN from current_buys for 2019-9 with price 177.91; prev price: 202.35
# New net worth: 1134901.6100000003
# Removed CTRA from current_buys for 2019-9 with price 13.54; prev price: 14.82
# New net worth: 1114355.0500000003
# Added HPQ to current_buys for 2019-9 with price 15.41
# Added TTWO to current_buys for 2019-9 with price 131.66
# Added ULTA to current_buys for 2019-9 with price 237.41
# Removed ULTA from current_buys for 2019-10 with price 265.99; prev price: 237.41
# New net worth: 1137562.0100000002
# Added ANET to current_buys for 2019-11 with price 46.33
# Removed BG from current_buys for 2019-11 with price 46.64; prev price: 47.99
# New net worth: 1136502.2600000002
# Added PCG to current_buys for 2019-11 with price 6.42
# Removed ANET from current_buys for 2019-12 with price 48.28; prev price: 46.33
# New net worth: 1145593.1600000004
# Removed PCG from current_buys for 2019-12 with price 7.85; prev price: 6.42
# New net worth: 1153755.6000000003
# Removed HPQ from current_buys for 2020-1 with price 17.96; prev price: 15.41
# New net worth: 1190633.7000000002
# Added SHW to current_buys for 2020-1 with price 182.69
# Added DVN to current_buys for 2020-2 with price 16.1
# Added PARA to current_buys for 2020-2 with price 28.97
# Removed PARA from current_buys for 2020-3 with price 21.29; prev price: 28.97
# New net worth: 1176464.1000000003
# Added PSX to current_buys for 2020-3 with price 62.01
# Removed SHW from current_buys for 2020-3 with price 172.42; prev price: 182.69
# New net worth: 1163082.2900000003
# Added SLB to current_buys for 2020-3 with price 25.46
# Removed PSX from current_buys for 2020-4 with price 40.87; prev price: 62.01
# New net worth: 1149700.6700000002
# Removed SLB from current_buys for 2020-4 with price 11.54; prev price: 25.46
# New net worth: 1026856.6700000002
# Added VTR to current_buys for 2020-4 with price 19.54
# Removed VTR from current_buys for 2020-5 with price 25.83; prev price: 19.54
# New net worth: 1067968.11
# Added EW to current_buys for 2020-7 with price 69.0
# Removed EW from current_buys for 2020-9 with price 85.91; prev price: 69.0
# New net worth: 1109346.8800000001
# Added MTCH to current_buys for 2020-9 with price 113.41
# Removed MTCH from current_buys for 2020-10 with price 116.21; prev price: 113.41
# New net worth: 1114535.28
# Added SLB to current_buys for 2020-10 with price 13.94
# Removed SLB from current_buys for 2020-11 with price 14.47; prev price: 13.94
# New net worth: 1122724.84
# Added SMCI to current_buys for 2020-11 with price 23.0
# Removed INTU from current_buys for 2020-12 with price 348.68; prev price: 235.62
# New net worth: 1217469.12
# Added MHK to current_buys for 2020-12 with price 126.73
# Removed SMCI from current_buys for 2020-12 with price 28.87; prev price: 23.0
# New net worth: 1274531.3900000001
# Added BG to current_buys for 2021-1 with price 59.51
# Added ETSY to current_buys for 2021-1 with price 172.08
# Removed ETSY from current_buys for 2021-2 with price 203.77; prev price: 172.08
# New net worth: 1288253.1600000001
# Removed MHK from current_buys for 2021-2 with price 145.85; prev price: 126.73
# New net worth: 1324982.6800000002
# Added ULTA to current_buys for 2021-2 with price 282.21
# Removed BBWI from current_buys for 2021-3 with price 43.28; prev price: 18.72
# New net worth: 1587357.1600000001
# Removed ULTA from current_buys for 2021-3 with price 337.42; prev price: 282.21
# New net worth: 1639199.35
# Added BBWI to current_buys for 2021-4 with price 47.14
# Added PARA to current_buys for 2021-4 with price 40.78
# Removed TTWO from current_buys for 2021-4 with price 180.15; prev price: 131.66
# New net worth: 1721244.4300000002
# Added WBD to current_buys for 2021-4 with price 43.31
# Added ARE to current_buys for 2021-5 with price 160.99
# Removed BG from current_buys for 2021-5 with price 78.23; prev price: 59.51
# New net worth: 1801422.1900000002
# Added INTU to current_buys for 2021-5 with price 403.15
# Removed PARA from current_buys for 2021-5 with price 36.23; prev price: 40.78
# New net worth: 1764844.7400000002
# Removed WBD from current_buys for 2021-5 with price 36.12; prev price: 43.31
# New net worth: 1707698.6200000003
# Removed BBWI from current_buys for 2021-6 with price 53.99; prev price: 47.14
# New net worth: 1755333.5200000003
# Added CTVA to current_buys for 2021-6 with price 44.44
# Removed INTU from current_buys for 2021-6 with price 429.93; prev price: 403.15
# New net worth: 1777587.7000000004
# Added MCK to current_buys for 2021-6 with price 188.31
# Added ORLY to current_buys for 2021-6 with price 537.65
# Added MAS to current_buys for 2021-7 with price 55.3
# Removed CTVA from current_buys for 2021-8 with price 41.07; prev price: 44.44
# New net worth: 1750968.0700000003
# Added GPN to current_buys for 2021-8 with price 167.48
# Removed MAS from current_buys for 2021-8 with price 55.79; prev price: 55.3
# New net worth: 1753177.4800000004
# Added XOM to current_buys for 2021-8 with price 50.74
# Removed EA from current_buys for 2021-9 with price 143.92; prev price: 92.52
# New net worth: 1775844.8800000004
# Removed GPN from current_buys for 2021-9 with price 158.43; prev price: 167.48
# New net worth: 1758315.0300000003
# Added LOW to current_buys for 2021-9 with price 192.09
# Removed MCK from current_buys for 2021-9 with price 199.73; prev price: 188.31
# New net worth: 1779864.5700000003
# Added NVDA to current_buys for 2021-9 with price 22.4
# Removed ORLY from current_buys for 2021-9 with price 592.54; prev price: 537.65
# New net worth: 1816146.8600000003
# Removed XOM from current_buys for 2021-9 with price 48.1; prev price: 50.74
# New net worth: 1803060.3800000004
# Removed NVDA from current_buys for 2021-10 with price 20.71; prev price: 22.4
# New net worth: 1776204.5900000003
# Added REGN to current_buys for 2021-10 with price 570.79
# Removed LOW from current_buys for 2021-11 with price 219.62; prev price: 192.09
# New net worth: 1826584.4900000005
# Removed REGN from current_buys for 2021-11 with price 639.15; prev price: 570.79
# New net worth: 1869104.4100000004
# Added ADSK to current_buys for 2021-12 with price 249.68
# Added ANET to current_buys for 2021-12 with price 121.39
# Added AXON to current_buys for 2021-12 with price 164.77
# Added CTRA to current_buys for 2021-12 with price 17.09
# Removed ADSK from current_buys for 2022-1 with price 283.72; prev price: 249.68
# New net worth: 1920062.2900000005
# Removed AXON from current_buys for 2022-1 with price 152.87; prev price: 164.77
# New net worth: 1893073.0900000003
# Removed CTRA from current_buys for 2022-1 with price 16.94; prev price: 17.09
# New net worth: 1890245.1400000004
# Removed ANET from current_buys for 2022-2 with price 124.3; prev price: 121.39
# New net worth: 1899205.0300000003
# Removed ARE from current_buys for 2022-2 with price 177.7; prev price: 160.99
# New net worth: 1918672.1800000002
# Added F to current_buys for 2022-2 with price 18.13
# Removed F from current_buys for 2022-3 with price 14.65; prev price: 18.13
# New net worth: 1845017.9800000002
# Added INTU to current_buys for 2022-3 with price 460.93
# Added VICI to current_buys for 2022-3 with price 24.5
# Added VTRS to current_buys for 2022-3 with price 9.08
# Removed INTU from current_buys for 2022-4 with price 476.02; prev price: 460.93
# New net worth: 1857089.9800000002
# Removed VICI from current_buys for 2022-4 with price 25.73; prev price: 24.5
# New net worth: 1875615.0100000002
# Removed VTRS from current_buys for 2022-4 with price 9.68; prev price: 9.08
# New net worth: 1899998.4100000001
# Added MSI to current_buys for 2022-5 with price 208.73
# Added NFLX to current_buys for 2022-5 with price 199.46
# Added ORLY to current_buys for 2022-5 with price 610.65
# Added VRSN to current_buys for 2022-5 with price 175.0
# Added BBWI to current_buys for 2022-6 with price 37.58
# Removed MSI from current_buys for 2022-6 with price 211.5; prev price: 208.73
# New net worth: 1905039.81
# Removed NFLX from current_buys for 2022-6 with price 192.91; prev price: 199.46
# New net worth: 1892562.06
# Added O to current_buys for 2022-6 with price 60.81
# Removed ORLY from current_buys for 2022-6 with price 624.61; prev price: 610.65
# New net worth: 1901245.18
# Removed VRSN from current_buys for 2022-6 with price 174.37; prev price: 175.0
# New net worth: 1899877.45
# Added WBD to current_buys for 2022-6 with price 17.66
# Removed BBWI from current_buys for 2022-7 with price 26.61; prev price: 37.58
# New net worth: 1858356.0
# Added CE to current_buys for 2022-7 with price 109.91
# Added CTVA to current_buys for 2022-7 with price 52.91
# Added FCX to current_buys for 2022-7 with price 28.27
# Removed WBD from current_buys for 2022-7 with price 14.25; prev price: 17.66
# New net worth: 1784986.44
# Removed CE from current_buys for 2022-8 with price 108.79; prev price: 109.91
# New net worth: 1781199.72
# Removed CTVA from current_buys for 2022-8 with price 55.63; prev price: 52.91
# New net worth: 1800305.0
# Removed FCX from current_buys for 2022-8 with price 29.12; prev price: 28.27
# New net worth: 1803869.0499999998
# Added NEM to current_buys for 2022-8 with price 41.59
# Added WBD to current_buys for 2022-8 with price 15.4
# Added BKNG to current_buys for 2022-9 with price 1843.63
# Added MRNA to current_buys for 2022-9 with price 138.95
# Removed NEM from current_buys for 2022-9 with price 37.86; prev price: 41.59
# New net worth: 1771515.0299999998
# Added NVDA to current_buys for 2022-9 with price 13.92
# Removed BKNG from current_buys for 2022-10 with price 1670.88; prev price: 1843.63
# New net worth: 1737828.7799999998
# Removed MRNA from current_buys for 2022-10 with price 120.99; prev price: 138.95
# New net worth: 1724107.3399999999
# Removed NVDA from current_buys for 2022-10 with price 12.5; prev price: 13.92
# New net worth: 1690598.18
# Added TSLA to current_buys for 2022-10 with price 242.4
# Added BKNG to current_buys for 2022-11 with price 1880.46
# Added META to current_buys for 2022-11 with price 95.0
# Removed TSLA from current_buys for 2022-11 with price 227.82; prev price: 242.4
# New net worth: 1670273.66
# Removed BKNG from current_buys for 2022-12 with price 2050.41; prev price: 1880.46
# New net worth: 1700694.7099999997
# Removed META from current_buys for 2022-12 with price 120.19; prev price: 95.0
# New net worth: 1710947.0399999998
# Removed O from current_buys for 2022-12 with price 57.39; prev price: 60.81
# New net worth: 1689660.96
# Added CSGP to current_buys for 2023-1 with price 77.65
# Added EQT to current_buys for 2023-1 with price 30.87
# Added TSLA to current_buys for 2023-1 with price 108.1
# Removed EQT from current_buys for 2023-2 with price 30.68; prev price: 30.87
# New net worth: 1687581.22
# Added MRNA to current_buys for 2023-2 with price 174.3
# Removed TSLA from current_buys for 2023-2 with price 181.41; prev price: 108.1
# New net worth: 1916748.2800000003
# Added CNP to current_buys for 2023-3 with price 26.23
# Removed CSGP from current_buys for 2023-3 with price 70.03; prev price: 77.65
# New net worth: 1883593.6600000004
# Removed DVN from current_buys for 2023-3 with price 51.57; prev price: 16.1
# New net worth: 2408194.9600000004
# Added TMUS to current_buys for 2023-3 with price 139.61
# Removed CNP from current_buys for 2023-4 with price 28.13; prev price: 26.23
# New net worth: 2435961.5600000005
# Removed TMUS from current_buys for 2023-4 with price 145.01; prev price: 139.61
# New net worth: 2454586.16
# Added ALB to current_buys for 2023-5 with price 174.84
# Added AON to current_buys for 2023-5 with price 320.08
# Added BKR to current_buys for 2023-5 with price 27.81
# Added CL to current_buys for 2023-5 with price 78.34
# Removed ALB from current_buys for 2023-6 with price 192.86; prev price: 174.84
# New net worth: 2505168.3000000003
# Removed BKR from current_buys for 2023-6 with price 27.74; prev price: 27.81
# New net worth: 2503932.66
# Removed CL from current_buys for 2023-6 with price 72.72; prev price: 78.34
# New net worth: 2483560.16
# Added CTVA to current_buys for 2023-6 with price 53.18
# Added DG to current_buys for 2023-6 with price 158.36
# Added MOS to current_buys for 2023-6 with price 30.93
# Removed AON from current_buys for 2023-7 with price 335.18; prev price: 320.08
# New net worth: 2506708.4600000004
# Added CL to current_buys for 2023-7 with price 74.9
# Removed CTVA from current_buys for 2023-7 with price 57.27; prev price: 53.18
# New net worth: 2544909.0600000005
# Removed DG from current_buys for 2023-7 with price 166.88; prev price: 158.36
# New net worth: 2571627.7800000007
# Removed MOS from current_buys for 2023-7 with price 34.87; prev price: 30.93
# New net worth: 2610015.200000001
# Added MTD to current_buys for 2023-7 with price 1312.14
# Removed CL from current_buys for 2023-8 with price 74.88; prev price: 74.9
# New net worth: 2609881.340000001
# Added DHR to current_buys for 2023-8 with price 224.29
# Removed MTD from current_buys for 2023-8 with price 1284.43; prev price: 1312.14
# New net worth: 2598880.4700000007
# Added NFLX to current_buys for 2023-8 with price 438.62
# Added UDR to current_buys for 2023-8 with price 38.75
# Added DG to current_buys for 2023-9 with price 127.9
# Removed DG from current_buys for 2023-10 with price 101.89; prev price: 127.9
# New net worth: 2529901.950000001
# Removed DHR from current_buys for 2023-10 with price 212.79; prev price: 224.29
# New net worth: 2503141.450000001
# Added NEE to current_buys for 2023-10 with price 50.91
# Removed NFLX from current_buys for 2023-10 with price 380.33; prev price: 438.62
# New net worth: 2434067.800000001
# Removed UDR from current_buys for 2023-10 with price 33.62; prev price: 38.75
# New net worth: 2365259.1100000013
# Added ALB to current_buys for 2023-11 with price 121.75
# Added ALGN to current_buys for 2023-11 with price 183.21
# Added CL to current_buys for 2023-11 with price 73.68
# Removed NEE from current_buys for 2023-11 with price 57.04; prev price: 50.91
# New net worth: 2425535.4000000013
# Added ON to current_buys for 2023-11 with price 64.84
# Added PAYC to current_buys for 2023-11 with price 149.4
# Removed ALB from current_buys for 2023-12 with price 124.91; prev price: 121.75
# New net worth: 2437812.0000000014
# Removed ALGN from current_buys for 2023-12 with price 220.45; prev price: 183.21
# New net worth: 2533965.6800000016
# Removed ON from current_buys for 2023-12 with price 74.18; prev price: 64.84
# New net worth: 2603838.2200000016
# Removed PAYC from current_buys for 2023-12 with price 184.55; prev price: 149.4
# New net worth: 2621659.270000002
# Added MKTX to current_buys for 2024-2 with price 216.11
# Added UDR to current_buys for 2024-2 with price 35.73
# Removed CL from current_buys for 2024-3 with price 85.56; prev price: 73.68
# New net worth: 2657192.350000002
# Added LLY to current_buys for 2024-3 with price 779.74
# Removed MKTX from current_buys for 2024-3 with price 216.03; prev price: 216.11
# New net worth: 2656998.2700000023
# Added PARA to current_buys for 2024-3 with price 10.85
# Added PODD to current_buys for 2024-3 with price 169.25
# Removed UDR from current_buys for 2024-3 with price 35.17; prev price: 35.73
# New net worth: 2648780.8300000024
# Added WMT to current_buys for 2024-3 with price 58.2
# Removed PODD from current_buys for 2024-4 with price 168.1; prev price: 169.25
# New net worth: 2646253.130000002
# Added GDDY to current_buys for 2024-5 with price 122.29
# Removed WMT from current_buys for 2024-5 with price 58.48; prev price: 58.2
# New net worth: 2648736.1700000023
# Removed WBD from current_buys
# Removed MRNA from current_buys
# Removed LLY from current_buys
# Removed PARA from current_buys
# Removed GDDY from current_buys
# 2711210.420000002
