# %% [markdown]
# # Random Forest Classification
# This programm is runs Random Forest Classification in order to predict wether stock is a good option to buy. Stock is classified as 'Buy' if it'll beat SP500 and ROI is above 2%.
# Randomized Search is used to optimize parameters for model's precision.

# %% [markdown]
# ### 1. Imports

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, confusion_matrix, classification_report, make_scorer, recall_score
from sklearn.preprocessing import StandardScaler
from scipy.stats import randint

# %% [markdown]
# ## First attempt (fewer data)

# %% [markdown]
# ### 2. Load the data

# %%
data = pd.read_csv('stocks_data.csv')
data.describe(include='all')
# Out:
#           Unnamed: 0 Ticker          Year         Month      MA Ratio  \
# count   14854.000000  14854  14854.000000  14854.000000  14854.000000
# unique           NaN    393           NaN           NaN           NaN
# top              NaN    AWK           NaN           NaN           NaN
# freq             NaN     55           NaN           NaN           NaN
# mean     7426.500000    NaN   2020.669113      6.223240      1.004148
# std      4288.124784    NaN      1.428016      3.520757      0.046473
# min         0.000000    NaN   2018.000000      1.000000      0.580721
# 25%      3713.250000    NaN   2019.000000      3.000000      0.977766
# 50%      7426.500000    NaN   2021.000000      6.000000      1.005360
# 75%     11139.750000    NaN   2022.000000      9.000000      1.031953
# max     14853.000000    NaN   2023.000000     12.000000      1.335656
#
#                  Buy        Result           ROE  Insider Ownership Growth  \
# count   14854.000000  14854.000000  14854.000000              14854.000000
# unique           NaN           NaN           NaN                       NaN
# top              NaN           NaN           NaN                       NaN
# freq             NaN           NaN           NaN                       NaN
# mean        0.415848      1.032817     39.494365                  0.015486
# std         0.492884      0.149260    181.839873                  0.269863
# min         0.000000      0.259712   -613.743387                 -0.633527
# 25%         0.000000      0.944153     10.160854                 -0.001350
# 50%         0.000000      1.028547     19.251991                  0.000000
# 75%         1.000000      1.113949     31.949569                  0.008000
# max         1.000000      3.142137  11300.330487                 17.759731
#
#         Institutional Ownership Growth  Forecast EPS Growth  \
# count                     14854.000000         14854.000000
# unique                             NaN                  NaN
# top                                NaN                  NaN
# freq                               NaN                  NaN
# mean                          0.026708             0.057775
# std                           0.230675             2.136724
# min                          -0.714136            -0.992366
# 25%                          -0.023114            -0.184264
# 50%                          -0.000648            -0.039062
# 75%                           0.033653             0.086957
# max                          14.203540           133.000000
#
#         Avg 2Q EPS Growth  Avg 2Q EPS Surprise  YoY EPS Growth  \
# count        14854.000000         14854.000000    14854.000000
# unique                NaN                  NaN             NaN
# top                   NaN                  NaN             NaN
# freq                  NaN                  NaN             NaN
# mean             0.181477            13.755183        0.369529
# std              2.111809            46.751483        3.637998
# min            -45.050000           -65.625000       -0.961538
# 25%             -0.040838             2.015000        0.017606
# 50%              0.045662             6.055000        0.130688
# 75%              0.154182            13.135000        0.275148
# max             78.553797          1493.215000      192.000000
#
#         Sector Performance  Market Performance  Benchmark SP500 Performance
# count         14854.000000        14854.000000                 14854.000000
# unique                 NaN                 NaN                          NaN
# top                    NaN                 NaN                          NaN
# freq                   NaN                 NaN                          NaN
# mean              1.488003            1.438443                     1.029219
# std               8.164589            7.038394                     0.077491
# min             -44.900728          -22.795349                     0.769903
# 25%              -3.453784           -3.160007                     0.983314
# 50%               1.496227            2.069271                     1.043101
# 75%               6.429508            5.507430                     1.080728
# max              31.971220           21.644623                     1.243323

# %% [markdown]
# ### 3. Split the data for train and test, standarise the data

# %%
data = data.reset_index(drop=True)
train_data = data[data['Year'] <= 2022]
test_data = data[data['Year'] > 2022]
x_train = train_data.drop(['Year', 'Buy', 'Month', 'Ticker', 'Result', 'Benchmark SP500 Performance', data.columns[0]], axis=1)
y_train = train_data['Buy']
x_test = test_data.drop(['Year', 'Buy', 'Month', 'Ticker', 'Result', 'Benchmark SP500 Performance', data.columns[0]], axis=1)
y_test = test_data['Buy']

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# ### 4. Train the model with randomized search

# %%
param_dist = {
    'n_estimators': randint(100, 800),
    'max_depth': randint(10, 50),
    'min_samples_split': randint(2, 20),
    'min_samples_leaf': randint(1, 10),
    'class_weight': [{0: 3, 1: 1}, {0: 5, 1: 2}, {0: 2, 1: 1}, {0: 8, 1: 5}, {0: 6, 1: 5}, {0: 5, 1: 6}, {0: 1, 1: 2}, None]
}
random_search = RandomizedSearchCV(estimator=RandomForestClassifier(random_state=42),
                                   param_distributions=param_dist,
                                   n_iter=20, 
                                   cv=5,
                                   scoring='precision',
                                   n_jobs=-1,
                                   verbose=2,
                                   random_state=42)
random_search.fit(x_train, y_train)
best_model = random_search.best_estimator_
print("Best Parameters:", random_search.best_params_)

y_pred = best_model.predict(x_test)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Parameters: {'class_weight': {0: 2, 1: 1}, 'max_depth': 31, 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 443}

# %% [markdown]
# ### 5. Evaluation

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print('Confusion Matrix:')
print(conf_matrix)
print('Classification Report:')
print(class_report)
# Out:
# Accuracy: 0.654434250764526
# Precision: 0.4224137931034483
# Confusion Matrix:
# [[1021   67]
#  [ 498   49]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      0.94      0.78      1088
#            1       0.42      0.09      0.15       547
#
#     accuracy                           0.65      1635
#    macro avg       0.55      0.51      0.47      1635
# weighted avg       0.59      0.65      0.57      1635

# %%
test_results = test_data.copy()
test_results['Predicted_Buy'] = y_pred

predicted_stocks_to_buy = test_results[test_results['Predicted_Buy'] == 1]
predicted_stocks_avg_return = predicted_stocks_to_buy['Result'].mean()

avg_stock_return = test_results['Result'].mean()

best_stocks = test_results[test_results['Buy'] == 1]
avg_best_stocks_return = best_stocks['Result'].mean()

sp500_return = predicted_stocks_to_buy['Benchmark SP500 Performance'].mean()

print("Benchmarks: ")
print(f"Average stock return (whole test sample): {avg_stock_return:.5f}")
print(f"'Buy' stocks average return: {avg_best_stocks_return:.5f}")
print(f"SP500 return: {sp500_return:.5f}")

print(f"\nModel's predicted stock average return: {predicted_stocks_avg_return:.5f}")
# Out:
# Benchmarks:
# Average stock return (whole test sample): 1.03164
# 'Buy' stocks average return: 1.17566
# SP500 return: 1.05889
#
# Model's predicted stock average return: 1.05902

# %% [markdown]
# ### 6. Conclusion
#
# The model demonstrates some promising aspects, although there is room for improvement. The precision for the positive class (class 1) is 42.24%, which, while not ideal, indicates that when the model does identify a positive case, there is a reasonable likelihood of success. Additionally, the model's predicted stock average return of 1.05902 slightly outperforms the S&P 500 return of 1.05889, showing that the model has potential in generating competitive returns.
#
# To further capitalize on this potential, enhancing recall for the positive class through more data, feature engineering, or alternative modeling approaches could be beneficial. By refining these areas, the model could become a more reliable tool for developing an effective investment strategy.

# %% [markdown]
# ## Second attempt (more data)
# In this attempt, data with a broader date range (from around 2008 for most companies) was used. This range includes several recession periods, providing greater diversity for the model to learn from. Additionally, columns containing information on the companies' Return on Assets and Return on Invested Capital were added.

# %% [markdown]
# ### 1. Read & preprocess the data

# %%
data = pd.read_csv('stocks_data4.csv')
data.describe(include='all')
# Out:
#           Unnamed: 0 Ticker          Year         Month         Price  \
# count   61517.000000  61517  61517.000000  61517.000000  61517.000000
# unique           NaN    417           NaN           NaN           NaN
# top              NaN    CPB           NaN           NaN           NaN
# freq             NaN    225           NaN           NaN           NaN
# mean    30758.000000    NaN   2015.561064      6.475576     86.090852
# std     17758.572592    NaN      5.130421      3.448068    145.204509
# min         0.000000    NaN   2005.000000      1.000000      0.170000
# 25%     15379.000000    NaN   2012.000000      3.000000     26.350000
# 50%     30758.000000    NaN   2016.000000      6.000000     49.240000
# 75%     46137.000000    NaN   2020.000000      9.000000     95.340000
# max     61516.000000    NaN   2024.000000     12.000000   3810.000000
#
#             MA Ratio           Buy        Result           ROE           ROA  \
# count   61517.000000  61517.000000  61517.000000  61517.000000  61517.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean        1.005282      0.454102      1.035127      0.262087      0.089610
# std         0.043844      0.497893      0.139926      8.540118      1.104599
# min         0.580721      0.000000      0.110349   -347.693570     -1.369770
# 25%         0.982233      0.000000      0.955759      0.095910      0.037540
# 50%         1.006824      0.000000      1.035871      0.166400      0.070180
# 75%         1.029836      1.000000      1.113424      0.266340      0.113230
# max         1.443446      1.000000      3.538378    509.372300    157.982210
#
#                  ROI  Insider Ownership Growth  \
# count   61517.000000              61517.000000
# unique           NaN                       NaN
# top              NaN                       NaN
# freq             NaN                       NaN
# mean        0.150720                  0.031192
# std         1.285496                  0.891108
# min       -15.336400                 -0.994779
# 25%         0.065280                 -0.003494
# 50%         0.114670                  0.000000
# 75%         0.186960                  0.008696
# max       181.327650                 76.000000
#
#         Institutional Ownership Growth  Forecast EPS Growth  \
# count                     61517.000000         61517.000000
# unique                             NaN                  NaN
# top                                NaN                  NaN
# freq                               NaN                  NaN
# mean                          0.025757             0.090401
# std                           0.250149             1.732801
# min                          -0.930676            -0.992366
# 25%                          -0.020228            -0.156716
# 50%                           0.000790            -0.016129
# 75%                           0.027434             0.110000
# max                          14.203540           133.000000
#
#         Avg 2Q EPS Growth  Avg 2Q EPS Surprise  YoY EPS Growth  \
# count        61517.000000         61517.000000    6.151700e+04
# unique                NaN                  NaN             NaN
# top                   NaN                  NaN             NaN
# freq                  NaN                  NaN             NaN
# mean             0.149241            11.124411    3.969275e+12
# std              1.515826            52.925722    4.301144e+14
# min            -58.668103           -93.235000   -1.000000e+00
# 25%             -0.036162             1.270000    1.214575e-02
# 50%              0.047591             4.740000    1.157895e-01
# 75%              0.157784            10.680000    2.425068e-01
# max             78.553797          3750.995000    5.764608e+16
#
#         Sector Performance  Market Performance  Benchmark SP500 Performance
# count         61517.000000        61517.000000                 61517.000000
# unique                 NaN                 NaN                          NaN
# top                    NaN                 NaN                          NaN
# freq                   NaN                 NaN                          NaN
# mean              1.641091            1.603703                     1.023901
# std               7.192112            6.071008                     0.072566
# min             -49.501466          -24.778692                     0.690014
# 25%              -2.055089           -1.243019                     0.989798
# 50%               2.177343            2.256661                     1.034544
# 75%               5.800866            5.367850                     1.066909
# max              43.727138           21.644623                     1.265488

# %% [markdown]
# ### 2. Split the data and train the model

# %%
cut_off_year = 2019

data = data.reset_index(drop=True)
train_data = data[(data['Year'] < cut_off_year) & ((data['Year'] != cut_off_year - 1) | (data['Month'] < 9))]
test_data = data[data['Year'] >= cut_off_year]
x_train = train_data.drop(['Year', 'Buy', 'Month', 'Ticker', 'Result', 'Benchmark SP500 Performance', 'Price', data.columns[0]], axis=1)
y_train = train_data['Buy']
x_test = test_data.drop(['Year', 'Buy', 'Month', 'Ticker', 'Result', 'Benchmark SP500 Performance', 'Price', data.columns[0]], axis=1)
y_test = test_data['Buy']

print(f"Amount of train data: {len(train_data)}")
print(f"Amount of test data: {len(test_data)}")

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
# Out:
# Amount of train data: 40199
# Amount of test data: 19829

# %%
param_dist = {
    'n_estimators': randint(100, 800),
    'max_depth': randint(10, 50),
    'min_samples_split': randint(2, 20),
    'min_samples_leaf': randint(1, 10),
    'class_weight': [{0: 3, 1: 1}, {0: 5, 1: 2}, {0: 2, 1: 1}, {0: 8, 1: 5}, {0: 6, 1: 5}, {0: 5, 1: 6}, {0: 1, 1: 2}, None]
}
random_search = RandomizedSearchCV(estimator=RandomForestClassifier(random_state=42),
                                   param_distributions=param_dist,
                                   n_iter=20, 
                                   cv=5,
                                   scoring='precision',
                                   n_jobs=-1,
                                   verbose=2,
                                   random_state=42)
random_search.fit(x_train, y_train)
best_model = random_search.best_estimator_
print("Best Parameters:", random_search.best_params_)

y_pred = best_model.predict(x_test)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Parameters: {'class_weight': {0: 2, 1: 1}, 'max_depth': 32, 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 763}

# %% [markdown]
# ### 3. Evaluate the model

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print('Confusion Matrix:')
print(conf_matrix)
print('Classification Report:')
print(class_report)
# Out:
# Accuracy: 0.5931716173281557
# Precision: 0.47116564417177914
# Confusion Matrix:
# [[11378   431]
#  [ 7636   384]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.60      0.96      0.74     11809
#            1       0.47      0.05      0.09      8020
#
#     accuracy                           0.59     19829
#    macro avg       0.53      0.51      0.41     19829
# weighted avg       0.55      0.59      0.47     19829

# %%
test_results = test_data.copy()
test_results['Predicted_Buy'] = y_pred

predicted_stocks_to_buy = test_results[test_results['Predicted_Buy'] == 1]
predicted_stocks_avg_return = predicted_stocks_to_buy['Result'].mean()

avg_stock_return = test_results['Result'].mean()

best_stocks = test_results[test_results['Buy'] == 1]
avg_best_stocks_return = best_stocks['Result'].mean()

sp500_return = predicted_stocks_to_buy['Benchmark SP500 Performance'].mean()

print("Benchmarks: ")
print(f"Average stock return (whole test sample): {avg_stock_return:.5f}")
print(f"'Buy' stocks average return: {avg_best_stocks_return:.5f}")
print(f"SP500 return: {sp500_return:.5f}")

print(f"\nModel's predicted stock average return: {predicted_stocks_avg_return:.5f}")
# Out:
# Benchmarks:
# Average stock return (whole test sample): 1.03403
# 'Buy' stocks average return: 1.16015
# SP500 return: 1.03479
#
# Model's predicted stock average return: 1.05352

# %% [markdown]
# ### 4. Conclusions
# As you can see, although the model has a lower average 3-month ROI from a single company, I believe it is better because it outperformed the benchmark, which was the return from the S&P 500 during the same investment periods. Despite its weak precision, I think a profitable investment strategy can be built from this model after refining other aspects.

# %% [markdown]
# ### 5. Simple example strategy - backtest

# %%
available_cash = 1000000
portfolio_worth = 1000000
current_buys = {}

backtest_data = test_results.copy()
backtest_data = backtest_data.sort_values(by=['Year', 'Month'])

def sell_stock(ticker, price):
    prev_price = current_buys[ticker]['price']
    amount = current_buys[ticker]['shares']

    global portfolio_worth, available_cash
    portfolio_worth -= prev_price * amount
    portfolio_worth += price * amount
    available_cash += price * amount

for index, row in backtest_data.iterrows():
    ticker = row['Ticker']
    prediction = row['Predicted_Buy']
    price = row['Price']

    if prediction == True:
        if ticker not in current_buys:
            allowed_spend = int(portfolio_worth / 5)
            
            if allowed_spend > available_cash:
                allowed_spend = available_cash

            if allowed_spend < portfolio_worth / 50:
                continue
                
            amount = int(allowed_spend / price)
            available_cash -= amount * price
            
            current_buys[ticker] = {'price': price, 'shares': amount, 'last_price': price}
            print(f"Added {ticker} to current_buys for {row['Year']}-{row['Month']} with price {price}")
        else:
            if price < current_buys[ticker]['price'] * 0.95: # Stop loss
                prev_price = current_buys[ticker]['price']
                
                sell_stock(ticker, price)
                del current_buys[ticker]
                
                print(f"Removed {ticker} from current_buys for {row['Year']}-{row['Month']} with price {price}; prev price: {prev_price}")
                print(f"New net worth: {portfolio_worth}")
            else:
                current_buys[ticker]['last_price'] = price
            
    else:
        if ticker in current_buys:
            prev_price = current_buys[ticker]['price']

            sell_stock(ticker, price)            
            del current_buys[ticker]
            
            print(f"Removed {ticker} from current_buys for {row['Year']}-{row['Month']} with price {price}; prev price: {prev_price}")
            print(f"New net worth: {portfolio_worth}")

for ticker in current_buys:
    sell_stock(ticker, current_buys[ticker]['last_price'])
    
    print(f"Removed {ticker} from current_buys")
    
print(portfolio_worth)
# Out:
# Added AAL to current_buys for 2019-3 with price 34.19
# Added BXP to current_buys for 2019-3 with price 102.66
# Added DPZ to current_buys for 2019-3 with price 236.41
# Added EXR to current_buys for 2019-3 with price 78.72
# Added GEN to current_buys for 2019-3 with price 11.77
# Removed AAL from current_buys for 2019-4 with price 31.93; prev price: 34.19
# New net worth: 986781.26
# Removed BXP from current_buys for 2019-4 with price 106.23; prev price: 102.66
# New net worth: 993735.6200000001
# Removed EXR from current_buys for 2019-4 with price 84.05; prev price: 78.72
# New net worth: 1007273.8200000001
# Removed GEN from current_buys for 2019-4 with price 12.12; prev price: 11.77
# New net worth: 1013221.02
# Added INTU to current_buys for 2019-4 with price 256.32
# Added LULU to current_buys for 2019-4 with price 165.52
# Added MAR to current_buys for 2019-4 with price 122.53
# Added META to current_buys for 2019-4 with price 168.35
# Removed DPZ from current_buys for 2019-5 with price 256.62; prev price: 236.41
# New net worth: 1030298.4700000001
# Added EIX to current_buys for 2019-5 with price 48.1
# Removed INTU from current_buys for 2019-5 with price 235.62; prev price: 256.32
# New net worth: 1013945.4700000002
# Added ISRG to current_buys for 2019-5 with price 165.68
# Removed MAR from current_buys for 2019-5 with price 133.5; prev price: 122.53
# New net worth: 1032078.8800000002
# Removed META from current_buys for 2019-5 with price 192.63; prev price: 168.35
# New net worth: 1061287.7200000002
# Added NI to current_buys for 2019-5 with price 22.88
# Added PSX to current_buys for 2019-5 with price 73.05
# Added REGN to current_buys for 2019-5 with price 340.79
# Removed EIX from current_buys for 2019-6 with price 48.33; prev price: 48.1
# New net worth: 1062272.81
# Added GDDY to current_buys for 2019-6 with price 70.29
# Removed ISRG from current_buys for 2019-6 with price 152.76; prev price: 165.68
# New net worth: 1046665.4500000001
# Removed LULU from current_buys for 2019-6 with price 163.87; prev price: 165.52
# New net worth: 1044645.8500000001
# Added LUV to current_buys for 2019-6 with price 45.29
# Removed NI from current_buys for 2019-6 with price 23.49; prev price: 22.88
# New net worth: 1050304.21
# Removed PSX from current_buys for 2019-6 with price 66.07; prev price: 73.05
# New net worth: 1030027.3099999999
# Removed REGN from current_buys for 2019-6 with price 303.95; prev price: 340.79
# New net worth: 1027006.4299999999
# Added ABBV to current_buys for 2019-7 with price 57.99
# Added AJG to current_buys for 2019-7 with price 83.67
# Added CPRT to current_buys for 2019-7 with price 18.74
# Removed LUV from current_buys for 2019-7 with price 49.03; prev price: 45.29
# New net worth: 1044259.0499999999
# Added MNST to current_buys for 2019-7 with price 32.38
# Removed ABBV from current_buys for 2019-8 with price 52.78; prev price: 57.99
# New net worth: 1025805.23
# Removed AJG from current_buys for 2019-8 with price 84.16; prev price: 83.67
# New net worth: 1027007.6900000001
# Removed CPRT from current_buys for 2019-8 with price 19.18; prev price: 18.74
# New net worth: 1031708.21
# Removed GDDY from current_buys for 2019-8 with price 74.23; prev price: 70.29
# New net worth: 1043319.3899999999
# Removed MNST from current_buys for 2019-8 with price 31.73; prev price: 32.38
# New net worth: 1039127.5399999999
# Added AJG to current_buys for 2019-9 with price 83.87
# Added BKNG to current_buys for 2019-9 with price 1932.47
# Added CPRT to current_buys for 2019-9 with price 18.69
# Added DE to current_buys for 2019-9 with price 140.65
# Added IDXX to current_buys for 2019-9 with price 286.08
# Removed AJG from current_buys for 2019-10 with price 82.66; prev price: 83.87
# New net worth: 1036130.3699999999
# Added BX to current_buys for 2019-10 with price 39.42
# Removed CPRT from current_buys for 2019-10 with price 19.88; prev price: 18.69
# New net worth: 1049361.98
# Removed DE from current_buys for 2019-10 with price 155.05; prev price: 140.65
# New net worth: 1070630.78
# Added GE to current_buys for 2019-10 with price 42.06
# Added NVR to current_buys for 2019-10 with price 3718.71
# Added WDC to current_buys for 2019-10 with price 56.91
# Removed BX from current_buys for 2019-11 with price 45.21; prev price: 39.42
# New net worth: 1100900.9
# Removed GE from current_buys for 2019-11 with price 50.71; prev price: 42.06
# New net worth: 1144929.4
# Added HD to current_buys for 2019-11 with price 210.13
# Added INTC to current_buys for 2019-11 with price 49.58
# Added ISRG to current_buys for 2019-11 with price 186.46
# Removed WDC from current_buys for 2019-11 with price 52.74; prev price: 56.91
# New net worth: 1143169.66
# Removed HD from current_buys for 2019-12 with price 192.67; prev price: 210.13
# New net worth: 1124155.7199999997
# Removed INTC from current_buys for 2019-12 with price 50.86; prev price: 49.58
# New net worth: 1130066.7599999998
# Removed ISRG from current_buys for 2019-12 with price 195.79; prev price: 186.46
# New net worth: 1131895.44
# Added MNST to current_buys for 2019-12 with price 29.91
# Added MPC to current_buys for 2019-12 with price 51.87
# Added PANW to current_buys for 2019-12 with price 74.9
# Removed MNST from current_buys for 2020-1 with price 31.85; prev price: 29.91
# New net worth: 1146577.3599999999
# Removed MPC from current_buys for 2020-1 with price 52.76; prev price: 51.87
# New net worth: 1150461.3199999998
# Removed PANW from current_buys for 2020-1 with price 78.47; prev price: 74.9
# New net worth: 1152974.5999999996
# Added BG to current_buys for 2020-2 with price 45.99
# Added ECL to current_buys for 2020-2 with price 191.9
# Added EL to current_buys for 2020-2 with price 186.85
# Removed BG from current_buys for 2020-3 with price 42.93; prev price: 45.99
# New net worth: 1137631.7599999995
# Removed ECL from current_buys for 2020-3 with price 182.08; prev price: 191.9
# New net worth: 1125837.9399999995
# Removed EL from current_buys for 2020-3 with price 184.6; prev price: 186.85
# New net worth: 1125050.4399999995
# Added EMN to current_buys for 2020-3 with price 54.08
# Removed EMN from current_buys for 2020-4 with price 39.67; prev price: 54.08
# New net worth: 1065104.8399999994
# Added DOC to current_buys for 2020-5 with price 20.09
# Added BMY to current_buys for 2020-6 with price 51.89
# Removed DOC from current_buys for 2020-6 with price 20.71; prev price: 20.09
# New net worth: 1071678.6999999993
# Added RTX to current_buys for 2020-6 with price 57.67
# Removed BMY from current_buys for 2020-7 with price 51.15; prev price: 51.89
# New net worth: 1068640.9999999993
# Added ED to current_buys for 2020-7 with price 62.48
# Removed RTX from current_buys for 2020-7 with price 55.41; prev price: 57.67
# New net worth: 1060242.8399999994
# Added TAP to current_buys for 2020-7 with price 32.17
# Removed ED from current_buys for 2020-8 with price 64.88; prev price: 62.48
# New net worth: 1068450.8399999994
# Added SLB to current_buys for 2020-8 with price 17.27
# Removed TAP from current_buys for 2020-8 with price 33.77; prev price: 32.17
# New net worth: 1078996.4399999995
# Added AMZN to current_buys for 2020-9 with price 174.96
# Added BMY to current_buys for 2020-9 with price 52.88
# Removed AMZN from current_buys for 2020-10 with price 161.06; prev price: 174.96
# New net worth: 1061857.7399999995
# Added BBY to current_buys for 2020-10 with price 98.54
# Removed BMY from current_buys for 2020-10 with price 52.27; prev price: 52.88
# New net worth: 1061591.1699999995
# Added BXP to current_buys for 2020-10 with price 68.65
# Removed SLB from current_buys for 2020-10 with price 13.94; prev price: 17.27
# New net worth: 1020389.0799999995
# Added TSLA to current_buys for 2020-10 with price 149.39
# Removed BBY from current_buys for 2020-11 with price 99.95; prev price: 98.54
# New net worth: 1023230.2299999995
# Added BMY to current_buys for 2020-11 with price 51.98
# Removed BXP from current_buys for 2020-11 with price 63.03; prev price: 68.65
# New net worth: 1021358.7699999996
# Added ETSY to current_buys for 2020-11 with price 126.44
# Removed TSLA from current_buys for 2020-11 with price 133.5; prev price: 149.39
# New net worth: 1003021.7099999995
# Added BBWI to current_buys for 2020-12 with price 29.67
# Removed BMY from current_buys for 2020-12 with price 54.53; prev price: 51.98
# New net worth: 1012908.0599999996
# Removed ETSY from current_buys for 2020-12 with price 154.67; prev price: 126.44
# New net worth: 1017594.2399999995
# Added ABT to current_buys for 2021-1 with price 102.04
# Added ADP to current_buys for 2021-1 with price 157.28
# Removed ABT from current_buys for 2021-2 with price 115.07; prev price: 102.04
# New net worth: 1043576.0599999995
# Added ALLE to current_buys for 2021-2 with price 104.87
# Added AMD to current_buys for 2021-2 with price 87.66
# Removed BBWI from current_buys for 2021-3 with price 43.28; prev price: 29.67
# New net worth: 1114239.1799999995
# Added DE to current_buys for 2021-3 with price 343.93
# Removed ADP from current_buys for 2021-4 with price 177.21; prev price: 157.28
# New net worth: 1118484.2699999996
# Removed ALLE from current_buys for 2021-4 with price 121.79; prev price: 104.87
# New net worth: 1152155.0699999996
# Removed AMD from current_buys for 2021-4 with price 81.09; prev price: 87.66
# New net worth: 1150591.4099999995
# Added APH to current_buys for 2021-4 with price 32.41
# Added AXON to current_buys for 2021-4 with price 143.06
# Removed DE from current_buys for 2021-4 with price 356.85; prev price: 343.93
# New net worth: 1158950.6499999994
# Added ED to current_buys for 2021-4 with price 65.5
# Removed APH from current_buys for 2021-5 with price 32.02; prev price: 32.41
# New net worth: 1156181.6499999994
# Removed AXON from current_buys for 2021-5 with price 148.98; prev price: 143.06
# New net worth: 1159135.7299999995
# Removed ED from current_buys for 2021-5 with price 68.55; prev price: 65.5
# New net worth: 1169890.0299999996
# Removed IDXX from current_buys for 2021-5 with price 549.88; prev price: 286.08
# New net worth: 1361408.8299999996
# Added DIS to current_buys for 2021-6 with price 177.44
# Added ED to current_buys for 2021-6 with price 68.05
# Added IDXX to current_buys for 2021-6 with price 550.59
# Added LULU to current_buys for 2021-6 with price 318.62
# Removed DIS from current_buys for 2021-7 with price 175.88; prev price: 177.44
# New net worth: 1359015.7899999996
# Removed ED from current_buys for 2021-7 with price 64.59; prev price: 68.05
# New net worth: 1345172.3299999996
# Added EXPD to current_buys for 2021-7 with price 122.95
# Added LLY to current_buys for 2021-7 with price 223.3
# Removed EXPD from current_buys for 2021-8 with price 122.28; prev price: 122.95
# New net worth: 1343706.3699999996
# Added HPQ to current_buys for 2021-8 with price 26.43
# Removed LLY from current_buys for 2021-8 with price 238.24; prev price: 223.3
# New net worth: 1361051.7099999995
# Added LYB to current_buys for 2021-8 with price 79.96
# Removed HPQ from current_buys for 2021-9 with price 26.5; prev price: 26.43
# New net worth: 1361760.2499999995
# Added HWM to current_buys for 2021-9 with price 31.6
# Removed IDXX from current_buys for 2021-9 with price 676.9; prev price: 550.59
# New net worth: 1424157.3899999997
# Removed LYB from current_buys for 2021-9 with price 79.94; prev price: 79.96
# New net worth: 1424089.3099999998
# Added MAR to current_buys for 2021-9 with price 131.61
# Added MCO to current_buys for 2021-9 with price 371.13
# Added NKE to current_buys for 2021-9 with price 159.28
# Removed HWM from current_buys for 2021-10 with price 32.12; prev price: 31.6
# New net worth: 1428570.6699999997
# Added INTU to current_buys for 2021-10 with price 533.77
# Removed LULU from current_buys for 2021-10 with price 401.37; prev price: 318.62
# New net worth: 1461339.6699999997
# Removed MCO from current_buys for 2021-10 with price 348.93; prev price: 371.13
# New net worth: 1444312.2699999998
# Added NDSN to current_buys for 2021-10 with price 232.02
# Removed NKE from current_buys for 2021-10 with price 142.34; prev price: 159.28
# New net worth: 1440348.3099999998
# Added POOL to current_buys for 2021-10 with price 423.14
# Removed INTU from current_buys for 2021-11 with price 598.15; prev price: 533.77
# New net worth: 1473697.1499999997
# Added LYB to current_buys for 2021-11 with price 77.07
# Removed MAR from current_buys for 2021-11 with price 157.97; prev price: 131.61
# New net worth: 1530740.1899999997
# Removed NDSN from current_buys for 2021-11 with price 250.66; prev price: 232.02
# New net worth: 1553928.3499999996
# Added STX to current_buys for 2021-11 with price 82.7
# Added ULTA to current_buys for 2021-11 with price 365.13
# Added VRTX to current_buys for 2021-11 with price 185.4
# Removed LYB from current_buys for 2021-12 with price 69.99; prev price: 77.07
# New net worth: 1526854.4299999997
# Added MCD to current_buys for 2021-12 with price 230.75
# Removed POOL from current_buys for 2021-12 with price 535.03; prev price: 423.14
# New net worth: 1572169.8799999997
# Added PWR to current_buys for 2021-12 with price 109.93
# Removed STX from current_buys for 2021-12 with price 93.45; prev price: 82.7
# New net worth: 1612557.6299999994
# Added SWK to current_buys for 2021-12 with price 156.98
# Removed ULTA from current_buys for 2021-12 with price 370.02; prev price: 365.13
# New net worth: 1616719.0199999996
# Removed VRTX from current_buys for 2021-12 with price 205.0; prev price: 185.4
# New net worth: 1621756.2199999995
# Added VTRS to current_buys for 2021-12 with price 10.72
# Added WBA to current_buys for 2021-12 with price 37.08
# Removed MCD from current_buys for 2022-1 with price 253.81; prev price: 230.75
# New net worth: 1648482.7599999995
# Removed PWR from current_buys for 2022-1 with price 111.75; prev price: 109.93
# New net worth: 1652073.6199999996
# Added REGN to current_buys for 2022-1 with price 627.1
# Added STLD to current_buys for 2022-1 with price 59.28
# Removed SWK from current_buys for 2022-1 with price 170.62; prev price: 156.98
# New net worth: 1680090.1799999997
# Added VRSN to current_buys for 2022-1 with price 252.11
# Removed VTRS from current_buys for 2022-1 with price 12.6; prev price: 10.72
# New net worth: 1736971.4599999995
# Added WAT to current_buys for 2022-1 with price 364.59
# Removed WBA from current_buys for 2022-1 with price 45.0; prev price: 37.08
# New net worth: 1752328.3399999994
# Added WBD to current_buys for 2022-1 with price 25.33
# Removed STLD from current_buys for 2022-2 with price 55.39; prev price: 59.28
# New net worth: 1740203.2099999995
# Removed VRSN from current_buys for 2022-2 with price 216.85; prev price: 252.11
# New net worth: 1693236.8899999994
# Removed WAT from current_buys for 2022-2 with price 323.72; prev price: 364.59
# New net worth: 1654328.6499999994
# Removed WBD from current_buys for 2022-2 with price 27.17; prev price: 25.33
# New net worth: 1664211.2899999996
# Added BMY to current_buys for 2022-3 with price 62.41
# Removed REGN from current_buys for 2022-3 with price 607.03; prev price: 627.1
# New net worth: 1653654.4699999995
# Added AAPL to current_buys for 2022-4 with price 171.91
# Added AOS to current_buys for 2022-4 with price 62.75
# Removed BKNG from current_buys for 2022-4 with price 2356.48; prev price: 1932.47
# New net worth: 1699023.5399999996
# Removed BMY from current_buys for 2022-4 with price 67.63; prev price: 62.41
# New net worth: 1726861.7999999996
# Added DGX to current_buys for 2022-4 with price 129.46
# Added FICO to current_buys for 2022-4 with price 449.29
# Added INTC to current_buys for 2022-4 with price 44.94
# Removed AAPL from current_buys for 2022-5 with price 155.79; prev price: 171.91
# New net worth: 1695863.0399999996
# Removed AOS from current_buys for 2022-5 with price 56.77; prev price: 62.75
# New net worth: 1664348.4399999995
# Added CRM to current_buys for 2022-5 with price 177.06
# Removed DGX from current_buys for 2022-5 with price 126.36; prev price: 129.46
# New net worth: 1656080.7399999993
# Removed FICO from current_buys for 2022-5 with price 374.09; prev price: 449.29
# New net worth: 1598327.1399999992
# Removed INTC from current_buys for 2022-5 with price 42.0; prev price: 44.94
# New net worth: 1587646.1199999992
# Added TMUS to current_buys for 2022-5 with price 124.89
# Added WBD to current_buys for 2022-5 with price 19.25
# Added AMP to current_buys for 2022-6 with price 261.02
# Added BR to current_buys for 2022-6 with price 138.98
# Removed CRM from current_buys for 2022-6 with price 175.56; prev price: 177.06
# New net worth: 1584827.6199999992
# Added HII to current_buys for 2022-6 with price 201.6
# Removed TMUS from current_buys for 2022-6 with price 132.96; prev price: 124.89
# New net worth: 1605341.5599999994
# Removed WBD from current_buys for 2022-6 with price 17.66; prev price: 19.25
# New net worth: 1579114.5099999993
# Added WM to current_buys for 2022-6 with price 152.86
# Removed AMP from current_buys for 2022-7 with price 229.68; prev price: 261.02
# New net worth: 1541005.0699999994
# Removed BR from current_buys for 2022-7 with price 141.27; prev price: 138.98
# New net worth: 1542495.8599999994
# Added DG to current_buys for 2022-7 with price 239.29
# Removed HII from current_buys for 2022-7 with price 211.66; prev price: 201.6
# New net worth: 1558310.1799999995
# Removed WM from current_buys for 2022-7 with price 150.69; prev price: 152.86
# New net worth: 1553826.9599999995
# Removed DG from current_buys for 2022-8 with price 244.86; prev price: 239.29
# New net worth: 1561006.6899999995
# Added INCY to current_buys for 2022-8 with price 77.4
# Added PEG to current_buys for 2022-8 with price 61.14
# Added TMUS to current_buys for 2022-8 with price 142.08
# Added APA to current_buys for 2022-9 with price 35.91
# Added BBWI to current_buys for 2022-9 with price 36.85
# Removed INCY from current_buys for 2022-9 with price 71.35; prev price: 77.4
# New net worth: 1536607.0399999996
# Added MAR to current_buys for 2022-9 with price 150.82
# Removed PEG from current_buys for 2022-9 with price 60.34; prev price: 61.14
# New net worth: 1532522.2399999995
# Added SMCI to current_buys for 2022-9 with price 63.3
# Removed APA from current_buys for 2022-10 with price 35.32; prev price: 35.91
# New net worth: 1527393.3699999996
# Added APH to current_buys for 2022-10 with price 34.05
# Removed BBWI from current_buys for 2022-10 with price 31.19; prev price: 36.85
# New net worth: 1511975.5299999998
# Added BIO to current_buys for 2022-10 with price 427.84
# Removed MAR from current_buys for 2022-10 with price 137.94; prev price: 150.82
# New net worth: 1487400.4899999998
# Added MDLZ to current_buys for 2022-10 with price 54.08
# Removed SMCI from current_buys for 2022-10 with price 57.07; prev price: 63.3
# New net worth: 1457234.8299999996
# Added SPG to current_buys for 2022-10 with price 81.99
# Removed APH from current_buys for 2022-11 with price 37.67; prev price: 34.05
# New net worth: 1489709.8499999996
# Removed BIO from current_buys for 2022-11 with price 358.35; prev price: 427.84
# New net worth: 1475464.3999999997
# Added BKNG to current_buys for 2022-11 with price 1880.46
# Added EQR to current_buys for 2022-11 with price 58.66
# Removed MDLZ from current_buys for 2022-11 with price 59.38; prev price: 54.08
# New net worth: 1501296.5999999996
# Added SMCI to current_buys for 2022-11 with price 71.86
# Removed SPG from current_buys for 2022-11 with price 102.59; prev price: 81.99
# New net worth: 1570718.5999999996
# Added AMT to current_buys for 2022-12 with price 208.83
# Added BAX to current_buys for 2022-12 with price 50.09
# Removed BKNG from current_buys for 2022-12 with price 2050.41; prev price: 1880.46
# New net worth: 1597230.7999999996
# Added CRL to current_buys for 2022-12 with price 226.2
# Removed EQR from current_buys for 2022-12 with price 59.95; prev price: 58.66
# New net worth: 1599827.5699999996
# Added FANG to current_buys for 2022-12 with price 131.93
# Removed SMCI from current_buys for 2022-12 with price 90.51; prev price: 71.86
# New net worth: 1674931.1199999996
# Added TAP to current_buys for 2022-12 with price 52.67
# Removed TMUS from current_buys for 2022-12 with price 150.0; prev price: 142.08
# New net worth: 1692331.3599999996
# Added XYL to current_buys for 2022-12 with price 111.42
# Removed AMT from current_buys for 2023-1 with price 204.07; prev price: 208.83
# New net worth: 1685172.3199999996
# Added ARE to current_buys for 2023-1 with price 135.21
# Removed BAX from current_buys for 2023-1 with price 48.8; prev price: 50.09
# New net worth: 1684355.7499999995
# Removed CRL from current_buys for 2023-1 with price 218.4; prev price: 226.2
# New net worth: 1673342.1499999997
# Added EA to current_buys for 2023-1 with price 121.55
# Removed FANG from current_buys for 2023-1 with price 119.79; prev price: 131.93
# New net worth: 1662197.6299999997
# Added FRT to current_buys for 2023-1 with price 96.07
# Removed TAP from current_buys for 2023-1 with price 47.37; prev price: 52.67
# New net worth: 1628489.6299999997
# Added TMUS to current_buys for 2023-1 with price 137.38
# Removed XYL from current_buys for 2023-1 with price 108.44; prev price: 111.42
# New net worth: 1619439.3699999996
# Removed ARE from current_buys for 2023-2 with price 153.19; prev price: 135.21
# New net worth: 1663004.9099999997
# Added DPZ to current_buys for 2023-2 with price 352.6
# Added DXCM to current_buys for 2023-2 with price 107.71
# Removed EA from current_buys for 2023-2 with price 115.57; prev price: 121.55
# New net worth: 1646541.9699999997
# Added EPAM to current_buys for 2023-2 with price 352.77
# Removed DPZ from current_buys for 2023-3 with price 295.7; prev price: 352.6
# New net worth: 1592885.2699999996
# Removed EPAM from current_buys for 2023-3 with price 305.59; prev price: 352.77
# New net worth: 1548866.3299999996
# Added FICO to current_buys for 2023-3 with price 682.79
# Removed FRT from current_buys for 2023-3 with price 99.79; prev price: 96.07
# New net worth: 1553304.2899999996
# Added HLT to current_buys for 2023-3 with price 144.76
# Added INTU to current_buys for 2023-3 with price 397.46
# Removed DXCM from current_buys for 2023-4 with price 115.24; prev price: 107.71
# New net worth: 1576549.3999999994
# Removed FICO from current_buys for 2023-4 with price 689.84; prev price: 682.79
# New net worth: 1579743.0499999993
# Removed HLT from current_buys for 2023-4 with price 138.86; prev price: 144.76
# New net worth: 1567081.6499999994
# Added IDXX to current_buys for 2023-4 with price 489.27
# Removed INTU from current_buys for 2023-4 with price 436.49; prev price: 397.46
# New net worth: 1575668.2499999995
# Added NKE to current_buys for 2023-4 with price 119.59
# Added OTIS to current_buys for 2023-4 with price 82.2
# Added PARA to current_buys for 2023-4 with price 21.38
# Removed IDXX from current_buys for 2023-5 with price 489.6; prev price: 489.27
# New net worth: 1575879.4499999995
# Added INTU to current_buys for 2023-5 with price 439.08
# Removed NKE from current_buys for 2023-5 with price 125.73; prev price: 119.59
# New net worth: 1592058.3499999994
# Removed OTIS from current_buys for 2023-5 with price 83.91; prev price: 82.2
# New net worth: 1598612.7799999993
# Removed PARA from current_buys for 2023-5 with price 23.0; prev price: 21.38
# New net worth: 1607636.1799999992
# Added PYPL to current_buys for 2023-5 with price 75.11
# Added REGN to current_buys for 2023-5 with price 806.72
# Removed TMUS from current_buys for 2023-5 with price 141.5; prev price: 137.38
# New net worth: 1616671.3399999994
# Added WAT to current_buys for 2023-5 with price 298.22
# Added BAX to current_buys for 2023-6 with price 39.99
# Removed INTU from current_buys for 2023-6 with price 418.85; prev price: 439.08
# New net worth: 1602247.3499999994
# Added JBHT to current_buys for 2023-6 with price 167.37
# Removed PYPL from current_buys for 2023-6 with price 63.05; prev price: 75.11
# New net worth: 1550630.5499999993
# Removed REGN from current_buys for 2023-6 with price 731.17; prev price: 806.72
# New net worth: 1520561.6499999992
# Added V to current_buys for 2023-6 with price 224.3
# Added VRSN to current_buys for 2023-6 with price 223.28
# Removed WAT from current_buys for 2023-6 with price 256.04; prev price: 298.22
# New net worth: 1474838.5299999993
# Added WST to current_buys for 2023-6 with price 340.57
# Removed BAX from current_buys for 2023-7 with price 43.33; prev price: 39.99
# New net worth: 1485346.1699999992
# Added CMS to current_buys for 2023-7 with price 57.33
# Removed JBHT from current_buys for 2023-7 with price 180.3; prev price: 167.37
# New net worth: 1508413.289999999
# Added KMX to current_buys for 2023-7 with price 82.16
# Removed V from current_buys for 2023-7 with price 235.66; prev price: 224.3
# New net worth: 1523806.0899999992
# Removed VRSN from current_buys for 2023-7 with price 222.91; prev price: 223.28
# New net worth: 1523380.219999999
# Added WBA to current_buys for 2023-7 with price 26.51
# Added WEC to current_buys for 2023-7 with price 85.08
# Removed WST from current_buys for 2023-7 with price 377.27; prev price: 340.57
# New net worth: 1553254.019999999
# Removed CMS from current_buys for 2023-8 with price 57.93; prev price: 57.33
# New net worth: 1554683.8199999991
# Removed KMX from current_buys for 2023-8 with price 84.08; prev price: 82.16
# New net worth: 1561732.139999999
# Removed WBA from current_buys for 2023-8 with price 27.01; prev price: 26.51
# New net worth: 1567478.1399999987
# Removed WEC from current_buys for 2023-8 with price 85.35; prev price: 85.08
# New net worth: 1568402.349999999
# Added ABNB to current_buys for 2023-9 with price 132.69
# Added DHI to current_buys for 2023-9 with price 119.2
# Added DLTR to current_buys for 2023-9 with price 118.74
# Added DVA to current_buys for 2023-9 with price 102.99
# Added HD to current_buys for 2023-9 with price 324.67
# Removed ABNB from current_buys for 2023-10 with price 136.56; prev price: 132.69
# New net worth: 1577551.029999999
# Added CPB to current_buys for 2023-10 with price 38.17
# Removed DHI from current_buys for 2023-10 with price 105.32; prev price: 119.2
# New net worth: 1541032.749999999
# Removed DLTR from current_buys for 2023-10 with price 104.66; prev price: 118.74
# New net worth: 1503847.4699999993
# Removed DVA from current_buys for 2023-10 with price 95.1; prev price: 102.99
# New net worth: 1479822.4199999992
# Removed HD from current_buys for 2023-10 with price 292.26; prev price: 324.67
# New net worth: 1469678.0899999992
# Added MOS to current_buys for 2023-10 with price 34.34
# Added STE to current_buys for 2023-10 with price 213.98
# Added UDR to current_buys for 2023-10 with price 33.62
# Added VRSK to current_buys for 2023-10 with price 235.27
# Removed CPB from current_buys for 2023-11 with price 39.66; prev price: 38.17
# New net worth: 1481992.939999999
# Added CVX to current_buys for 2023-11 with price 138.03
# Added ECL to current_buys for 2023-11 with price 165.92
# Removed MOS from current_buys for 2023-11 with price 31.67; prev price: 34.34
# New net worth: 1459140.409999999
# Added NSC to current_buys for 2023-11 with price 185.76
# Removed STE from current_buys for 2023-11 with price 211.44; prev price: 213.98
# New net worth: 1455652.9899999988
# Added TECH to current_buys for 2023-11 with price 52.59
# Removed UDR from current_buys for 2023-11 with price 30.41; prev price: 33.62
# New net worth: 1427591.1699999988
# Removed VRSK from current_buys for 2023-11 with price 221.23; prev price: 235.27
# New net worth: 1423982.889999999
# Added WM to current_buys for 2023-11 with price 162.18
# Added WST to current_buys for 2023-11 with price 320.94
# Removed CVX from current_buys for 2023-12 with price 140.3; prev price: 138.03
# New net worth: 1428856.5799999991
# Removed ECL from current_buys for 2023-12 with price 190.92; prev price: 165.92
# New net worth: 1433606.5799999991
# Added EL to current_buys for 2023-12 with price 130.65
# Added LLY to current_buys for 2023-12 with price 581.27
# Removed NSC from current_buys for 2023-12 with price 222.75; prev price: 185.76
# New net worth: 1487574.9899999993
# Removed TECH from current_buys for 2023-12 with price 64.36; prev price: 52.59
# New net worth: 1552568.9299999992
# Removed WM from current_buys for 2023-12 with price 172.54; prev price: 162.18
# New net worth: 1570761.0899999992
# Removed WST from current_buys for 2023-12 with price 351.19; prev price: 320.94
# New net worth: 1574330.5899999992
# Added AON to current_buys for 2024-1 with price 286.15
# Added APTV to current_buys for 2024-1 with price 90.17
# Added ARE to current_buys for 2024-1 with price 126.63
# Added BWA to current_buys for 2024-1 with price 35.7
# Removed EL from current_buys for 2024-1 with price 144.03; prev price: 130.65
# New net worth: 1603686.3099999991
# Added FICO to current_buys for 2024-1 with price 1131.16
# Removed LLY from current_buys for 2024-1 with price 589.39; prev price: 581.27
# New net worth: 1604392.749999999
# Added LUV to current_buys for 2024-1 with price 28.15
# Removed AON from current_buys for 2024-2 with price 298.67; prev price: 286.15
# New net worth: 1618164.749999999
# Added APA to current_buys for 2024-2 with price 30.32
# Removed APTV from current_buys for 2024-2 with price 83.5; prev price: 90.17
# New net worth: 1594879.779999999
# Added ATO to current_buys for 2024-2 with price 113.45
# Removed BWA from current_buys for 2024-2 with price 34.25; prev price: 35.7
# New net worth: 1591598.429999999
# Added CBRE to current_buys for 2024-2 with price 86.19
# Removed FICO from current_buys for 2024-2 with price 1243.17; prev price: 1131.16
# New net worth: 1622849.219999999
# Added MAS to current_buys for 2024-2 with price 68.3
# Removed ATO from current_buys for 2024-3 with price 111.24; prev price: 113.45
# New net worth: 1617076.6999999988
# Added AWK to current_buys for 2024-3 with price 118.36
# Removed CBRE from current_buys for 2024-3 with price 92.98; prev price: 86.19
# New net worth: 1623187.6999999988
# Added CNP to current_buys for 2024-3 with price 27.05
# Removed MAS from current_buys for 2024-3 with price 76.98; prev price: 68.3
# New net worth: 1664435.0599999987
# Added MCD to current_buys for 2024-3 with price 288.87
# Removed APA from current_buys for 2024-4 with price 34.88; prev price: 30.32
# New net worth: 1713103.9399999988
# Removed AWK from current_buys for 2024-4 with price 118.97; prev price: 118.36
# New net worth: 1714716.1699999988
# Removed CNP from current_buys for 2024-4 with price 28.01; prev price: 27.05
# New net worth: 1717687.3699999987
# Removed MCD from current_buys for 2024-4 with price 278.43; prev price: 288.87
# New net worth: 1705660.4899999988
# Added ANSS to current_buys for 2024-5 with price 321.48
# Added CLX to current_buys for 2024-5 with price 138.46
# Added CPT to current_buys for 2024-5 with price 97.63
# Added DHI to current_buys for 2024-5 with price 142.24
# Removed NVR from current_buys
# Removed ARE from current_buys
# Removed LUV from current_buys
# Removed ANSS from current_buys
# Removed CLX from current_buys
# Removed CPT from current_buys
# Removed DHI from current_buys
# 1710864.0199999989
