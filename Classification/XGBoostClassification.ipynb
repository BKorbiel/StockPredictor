# %% [markdown]
# # XGBoost Classification
# This programm is an attempt to predict valuable stocks by XGBoost Classification.

# %% [markdown]
# ### 1. Imports

# %%
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import accuracy_score, precision_score, confusion_matrix, classification_report, make_scorer
from sklearn.preprocessing import StandardScaler
from scipy.stats import randint, uniform

# %% [markdown]
# ## First attempt (fewer data)

# %% [markdown]
# ### 2. Load the data

# %%
data = pd.read_csv('stocks_data.csv')
data.describe(include='all')
# Out:
#           Unnamed: 0 Ticker          Year         Month      MA Ratio  \
# count   14854.000000  14854  14854.000000  14854.000000  14854.000000
# unique           NaN    393           NaN           NaN           NaN
# top              NaN    AWK           NaN           NaN           NaN
# freq             NaN     55           NaN           NaN           NaN
# mean     7426.500000    NaN   2020.669113      6.223240      1.004148
# std      4288.124784    NaN      1.428016      3.520757      0.046473
# min         0.000000    NaN   2018.000000      1.000000      0.580721
# 25%      3713.250000    NaN   2019.000000      3.000000      0.977766
# 50%      7426.500000    NaN   2021.000000      6.000000      1.005360
# 75%     11139.750000    NaN   2022.000000      9.000000      1.031953
# max     14853.000000    NaN   2023.000000     12.000000      1.335656
#
#                  Buy        Result           ROE  Insider Ownership Growth  \
# count   14854.000000  14854.000000  14854.000000              14854.000000
# unique           NaN           NaN           NaN                       NaN
# top              NaN           NaN           NaN                       NaN
# freq             NaN           NaN           NaN                       NaN
# mean        0.415848      1.032817     39.494365                  0.015486
# std         0.492884      0.149260    181.839873                  0.269863
# min         0.000000      0.259712   -613.743387                 -0.633527
# 25%         0.000000      0.944153     10.160854                 -0.001350
# 50%         0.000000      1.028547     19.251991                  0.000000
# 75%         1.000000      1.113949     31.949569                  0.008000
# max         1.000000      3.142137  11300.330487                 17.759731
#
#         Institutional Ownership Growth  Forecast EPS Growth  \
# count                     14854.000000         14854.000000
# unique                             NaN                  NaN
# top                                NaN                  NaN
# freq                               NaN                  NaN
# mean                          0.026708             0.057775
# std                           0.230675             2.136724
# min                          -0.714136            -0.992366
# 25%                          -0.023114            -0.184264
# 50%                          -0.000648            -0.039062
# 75%                           0.033653             0.086957
# max                          14.203540           133.000000
#
#         Avg 2Q EPS Growth  Avg 2Q EPS Surprise  YoY EPS Growth  \
# count        14854.000000         14854.000000    14854.000000
# unique                NaN                  NaN             NaN
# top                   NaN                  NaN             NaN
# freq                  NaN                  NaN             NaN
# mean             0.181477            13.755183        0.369529
# std              2.111809            46.751483        3.637998
# min            -45.050000           -65.625000       -0.961538
# 25%             -0.040838             2.015000        0.017606
# 50%              0.045662             6.055000        0.130688
# 75%              0.154182            13.135000        0.275148
# max             78.553797          1493.215000      192.000000
#
#         Sector Performance  Market Performance  Benchmark SP500 Performance
# count         14854.000000        14854.000000                 14854.000000
# unique                 NaN                 NaN                          NaN
# top                    NaN                 NaN                          NaN
# freq                   NaN                 NaN                          NaN
# mean              1.488003            1.438443                     1.029219
# std               8.164589            7.038394                     0.077491
# min             -44.900728          -22.795349                     0.769903
# 25%              -3.453784           -3.160007                     0.983314
# 50%               1.496227            2.069271                     1.043101
# 75%               6.429508            5.507430                     1.080728
# max              31.971220           21.644623                     1.243323

# %% [markdown]
# ### 3. Split the data for train and test, standarise the data

# %%
data = data.reset_index(drop=True)
train_data = data[data['Year'] <= 2022]
test_data = data[data['Year'] > 2022]
x_train = train_data.drop(['Year', 'Buy', 'Month', 'Ticker', 'Result', 'Benchmark SP500 Performance', data.columns[0]], axis=1)
y_train = train_data['Buy']
x_test = test_data.drop(['Year', 'Buy', 'Month', 'Ticker', 'Result', 'Benchmark SP500 Performance', data.columns[0]], axis=1)
y_test = test_data['Buy']

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# ### 4. Train the model with randomized search

# %%
xg_clf = xgb.XGBClassifier(objective='binary:logistic')
param_dist = {
    'max_depth': randint(3, 8),
    'subsample': uniform(0.5, 0.5),
    'eta': uniform(0.01, 0.2),
    'colsample_bytree': uniform(0.6, 0.4),
    'min_child_weight': randint(1, 5),
    'gamma': uniform(0.0, 0.4),
    'lambda': uniform(0.0, 10.0),
    'alpha': uniform(0.0, 10.0),
    'scale_pos_weight': uniform(0.8, 5.0)
}

random_search = RandomizedSearchCV(estimator=xg_clf,
                                   param_distributions=param_dist,
                                   n_iter=50, 
                                   cv=10,
                                   scoring='precision',
                                   n_jobs=-1,
                                   verbose=2,
                                   random_state=42)
random_search.fit(x_train, y_train)
best_model = random_search.best_estimator_
print("Best Parameters:", random_search.best_params_)

y_pred = best_model.predict(x_test)
# Out:
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Best Parameters: {'alpha': 3.418796667164016, 'colsample_bytree': 0.6367196263253767, 'eta': 0.028831397653712024, 'gamma': 0.12456532375651769, 'lambda': 9.795105286215085, 'max_depth': 7, 'min_child_weight': 4, 'scale_pos_weight': 0.8858055091587512, 'subsample': 0.8816822115019555}

# %% [markdown]
# ### 5. Evaluation

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print('Confusion Matrix:')
print(conf_matrix)
print('Classification Report:')
print(class_report)
# Out:
# Accuracy: 0.6574923547400612
# Precision: 0.43434343434343436
# Confusion Matrix:
# [[1032   56]
#  [ 504   43]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      0.95      0.79      1088
#            1       0.43      0.08      0.13       547
#
#     accuracy                           0.66      1635
#    macro avg       0.55      0.51      0.46      1635
# weighted avg       0.59      0.66      0.57      1635

# %%
test_results = test_data.copy()
test_results['Predicted_Buy'] = y_pred

predicted_stocks_to_buy = test_results[test_results['Predicted_Buy'] == 1]
predicted_stocks_avg_return = predicted_stocks_to_buy['Result'].mean()

avg_stock_return = test_results['Result'].mean()

best_stocks = test_results[test_results['Buy'] == 1]
avg_best_stocks_return = best_stocks['Result'].mean()

sp500_return = predicted_stocks_to_buy['Benchmark SP500 Performance'].mean()

print("Benchmarks: ")
print(f"Average stock return (whole test sample): {avg_stock_return:.5f}")
print(f"'Buy' stocks average return: {avg_best_stocks_return:.5f}")
print(f"SP500 return: {sp500_return:.5f}")

print(f"\nModel's predicted stock average return: {predicted_stocks_avg_return:.5f}")
# Out:
# Benchmarks:
# Average stock return (whole test sample): 1.03164
# 'Buy' stocks average return: 1.17566
# SP500 return: 1.05484
#
# Model's predicted stock average return: 1.03850

# %% [markdown]
# ### 6. Conclusion
# Despite numerous attempts, I was unable to find a model that surpasses the SP500 benchmark. The best XGBoost model achieved only 43% precision and a three-month ROI of 3.9% (with an equal distribution of capital). While this exceeds the average ROI for the entire test sample, it does not outperform the SP500 benchmark (the key difference is that the SP500 has an unequal capital distribution, meaning that some large companies may contribute significantly more to the overall ROI)

# %% [markdown]
# ## Second attempt (more data)
# In this attempt, data with a broader date range (from around 2008 for most companies) was used. This range includes several recession periods, providing greater diversity for the model to learn from. Additionally, columns containing information on the companies' Return on Assets and Return on Invested Capital were added.

# %% [markdown]
# ### 1. Read & preprocess the data

# %%
data = pd.read_csv('stocks_data4.csv')
data.describe(include='all')
# Out:
#           Unnamed: 0 Ticker          Year         Month         Price  \
# count   61517.000000  61517  61517.000000  61517.000000  61517.000000
# unique           NaN    417           NaN           NaN           NaN
# top              NaN    CPB           NaN           NaN           NaN
# freq             NaN    225           NaN           NaN           NaN
# mean    30758.000000    NaN   2015.561064      6.475576     86.090852
# std     17758.572592    NaN      5.130421      3.448068    145.204509
# min         0.000000    NaN   2005.000000      1.000000      0.170000
# 25%     15379.000000    NaN   2012.000000      3.000000     26.350000
# 50%     30758.000000    NaN   2016.000000      6.000000     49.240000
# 75%     46137.000000    NaN   2020.000000      9.000000     95.340000
# max     61516.000000    NaN   2024.000000     12.000000   3810.000000
#
#             MA Ratio           Buy        Result           ROE           ROA  \
# count   61517.000000  61517.000000  61517.000000  61517.000000  61517.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean        1.005282      0.454102      1.035127      0.262087      0.089610
# std         0.043844      0.497893      0.139926      8.540118      1.104599
# min         0.580721      0.000000      0.110349   -347.693570     -1.369770
# 25%         0.982233      0.000000      0.955759      0.095910      0.037540
# 50%         1.006824      0.000000      1.035871      0.166400      0.070180
# 75%         1.029836      1.000000      1.113424      0.266340      0.113230
# max         1.443446      1.000000      3.538378    509.372300    157.982210
#
#                  ROI  Insider Ownership Growth  \
# count   61517.000000              61517.000000
# unique           NaN                       NaN
# top              NaN                       NaN
# freq             NaN                       NaN
# mean        0.150720                  0.031192
# std         1.285496                  0.891108
# min       -15.336400                 -0.994779
# 25%         0.065280                 -0.003494
# 50%         0.114670                  0.000000
# 75%         0.186960                  0.008696
# max       181.327650                 76.000000
#
#         Institutional Ownership Growth  Forecast EPS Growth  \
# count                     61517.000000         61517.000000
# unique                             NaN                  NaN
# top                                NaN                  NaN
# freq                               NaN                  NaN
# mean                          0.025757             0.090401
# std                           0.250149             1.732801
# min                          -0.930676            -0.992366
# 25%                          -0.020228            -0.156716
# 50%                           0.000790            -0.016129
# 75%                           0.027434             0.110000
# max                          14.203540           133.000000
#
#         Avg 2Q EPS Growth  Avg 2Q EPS Surprise  YoY EPS Growth  \
# count        61517.000000         61517.000000    6.151700e+04
# unique                NaN                  NaN             NaN
# top                   NaN                  NaN             NaN
# freq                  NaN                  NaN             NaN
# mean             0.149241            11.124411    3.969275e+12
# std              1.515826            52.925722    4.301144e+14
# min            -58.668103           -93.235000   -1.000000e+00
# 25%             -0.036162             1.270000    1.214575e-02
# 50%              0.047591             4.740000    1.157895e-01
# 75%              0.157784            10.680000    2.425068e-01
# max             78.553797          3750.995000    5.764608e+16
#
#         Sector Performance  Market Performance  Benchmark SP500 Performance
# count         61517.000000        61517.000000                 61517.000000
# unique                 NaN                 NaN                          NaN
# top                    NaN                 NaN                          NaN
# freq                   NaN                 NaN                          NaN
# mean              1.641091            1.603703                     1.023901
# std               7.192112            6.071008                     0.072566
# min             -49.501466          -24.778692                     0.690014
# 25%              -2.055089           -1.243019                     0.989798
# 50%               2.177343            2.256661                     1.034544
# 75%               5.800866            5.367850                     1.066909
# max              43.727138           21.644623                     1.265488

# %%
cut_off_year = 2019

data = data.reset_index(drop=True)
train_data = data[(data['Year'] < cut_off_year) & ((data['Year'] != cut_off_year - 1) | (data['Month'] < 9))]
test_data = data[data['Year'] >= cut_off_year]
x_train = train_data.drop(['Year', 'Buy', 'Month', 'Ticker', 'Result', 'Benchmark SP500 Performance', 'Price', data.columns[0]], axis=1)
y_train = train_data['Buy']
x_test = test_data.drop(['Year', 'Buy', 'Month', 'Ticker', 'Result', 'Benchmark SP500 Performance', 'Price', data.columns[0]], axis=1)
y_test = test_data['Buy']

print(f"Amount of train data: {len(train_data)}")
print(f"Amount of test data: {len(test_data)}")

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
# Out:
# Amount of train data: 40199
# Amount of test data: 19829

# %% [markdown]
# ### 2. Split the data and train the model

# %%
xg_clf = xgb.XGBClassifier(objective='binary:logistic')
param_dist = {
    'max_depth': randint(3, 8),
    'subsample': uniform(0.5, 0.5),
    'eta': uniform(0.01, 0.2),
    'colsample_bytree': uniform(0.6, 0.4),
    'min_child_weight': randint(1, 5),
    'gamma': uniform(0.0, 0.4),
    'lambda': uniform(0.0, 10.0),
    'alpha': uniform(0.0, 10.0),
    'scale_pos_weight': uniform(0.7, 1.2)
}

random_search = RandomizedSearchCV(estimator=xg_clf,
                                   param_distributions=param_dist,
                                   n_iter=100, 
                                   cv=10,
                                   scoring='precision',
                                   n_jobs=-1,
                                   verbose=2,
                                   random_state=42)
random_search.fit(x_train, y_train)
best_model = random_search.best_estimator_
print("Best Parameters:", random_search.best_params_)

y_pred = best_model.predict(x_test)
# Out:
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Best Parameters: {'alpha': 3.418796667164016, 'colsample_bytree': 0.6367196263253767, 'eta': 0.028831397653712024, 'gamma': 0.12456532375651769, 'lambda': 9.795105286215085, 'max_depth': 7, 'min_child_weight': 4, 'scale_pos_weight': 0.7205933221981002, 'subsample': 0.8816822115019555}

# %% [markdown]
# ### 3. Evaluation

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print('Confusion Matrix:')
print(conf_matrix)
print('Classification Report:')
print(class_report)
# Out:
# Accuracy: 0.5960461949669675
# Precision: 0.5072886297376094
# Confusion Matrix:
# [[11471   338]
#  [ 7672   348]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.60      0.97      0.74     11809
#            1       0.51      0.04      0.08      8020
#
#     accuracy                           0.60     19829
#    macro avg       0.55      0.51      0.41     19829
# weighted avg       0.56      0.60      0.47     19829

# %%
test_results = test_data.copy()
test_results['Predicted_Buy'] = y_pred

predicted_stocks_to_buy = test_results[test_results['Predicted_Buy'] == 1]
predicted_stocks_avg_return = predicted_stocks_to_buy['Result'].mean()

avg_stock_return = test_results['Result'].mean()

best_stocks = test_results[test_results['Buy'] == 1]
avg_best_stocks_return = best_stocks['Result'].mean()

sp500_return = predicted_stocks_to_buy['Benchmark SP500 Performance'].mean()

print("Benchmarks: ")
print(f"Average stock return (whole test sample): {avg_stock_return:.5f}")
print(f"'Buy' stocks average return: {avg_best_stocks_return:.5f}")
print(f"SP500 return: {sp500_return:.5f}")

print(f"\nModel's predicted stock average return: {predicted_stocks_avg_return:.5f}")
# Out:
# Benchmarks:
# Average stock return (whole test sample): 1.03403
# 'Buy' stocks average return: 1.16015
# SP500 return: 1.02983
#
# Model's predicted stock average return: 1.05702

# %% [markdown]
# ### 4. Conclusions
# Again, with greater dataset to train on, the model achieved much higher results. Not only the average 3-Month investment return was almost 6%, but also it's much higher than SP500 result in the same investment periods. I suspect one can build profitable investment strategy with this prediction model.

# %%
available_cash = 1000000
portfolio_worth = 1000000
current_buys = {}

backtest_data = test_results.copy()
backtest_data = backtest_data.sort_values(by=['Year', 'Month'])

def sell_stock(ticker, price):
    prev_price = current_buys[ticker]['price']
    amount = current_buys[ticker]['shares']

    global portfolio_worth, available_cash
    portfolio_worth -= prev_price * amount
    portfolio_worth += price * amount
    available_cash += price * amount

for index, row in backtest_data.iterrows():
    ticker = row['Ticker']
    prediction = row['Predicted_Buy']
    price = row['Price']

    if prediction == True:
        if ticker not in current_buys:
            allowed_spend = int(portfolio_worth / 5)
            
            if allowed_spend > available_cash:
                allowed_spend = available_cash

            if allowed_spend < portfolio_worth / 50:
                continue
                
            amount = int(allowed_spend / price)
            available_cash -= amount * price
            
            current_buys[ticker] = {'price': price, 'shares': amount, 'last_price': price}
            print(f"Added {ticker} to current_buys for {row['Year']}-{row['Month']} with price {price}")
        else:
            if price < current_buys[ticker]['price'] * 0.95: # Stop loss
                prev_price = current_buys[ticker]['price']
                
                sell_stock(ticker, price)
                del current_buys[ticker]
                
                print(f"Removed {ticker} from current_buys for {row['Year']}-{row['Month']} with price {price}; prev price: {prev_price}")
                print(f"New net worth: {portfolio_worth}")
            else:
                current_buys[ticker]['last_price'] = price
            
    else:
        if ticker in current_buys:
            prev_price = current_buys[ticker]['price']

            sell_stock(ticker, price)            
            del current_buys[ticker]
            
            print(f"Removed {ticker} from current_buys for {row['Year']}-{row['Month']} with price {price}; prev price: {prev_price}")
            print(f"New net worth: {portfolio_worth}")

for ticker in current_buys:
    sell_stock(ticker, current_buys[ticker]['last_price'])
    
    print(f"Removed {ticker} from current_buys")
    
print(portfolio_worth)
# Out:
# Added AMZN to current_buys for 2019-3 with price 83.59
# Added ANSS to current_buys for 2019-3 with price 182.23
# Added BXP to current_buys for 2019-3 with price 102.66
# Added DIS to current_buys for 2019-3 with price 111.75
# Added EXR to current_buys for 2019-3 with price 78.72
# Removed AMZN from current_buys for 2019-4 with price 90.71; prev price: 83.59
# New net worth: 1017031.0399999999
# Removed ANSS from current_buys for 2019-4 with price 187.45; prev price: 182.23
# New net worth: 1022757.38
# Removed BXP from current_buys for 2019-4 with price 106.23; prev price: 102.66
# New net worth: 1029711.74
# Removed DIS from current_buys for 2019-4 with price 110.28; prev price: 111.75
# New net worth: 1027081.91
# Removed EXR from current_buys for 2019-4 with price 84.05; prev price: 78.72
# New net worth: 1040620.1100000001
# Added CTRA to current_buys for 2019-5 with price 20.02
# Added NI to current_buys for 2019-5 with price 22.88
# Added UDR to current_buys for 2019-5 with price 36.89
# Removed CTRA from current_buys for 2019-6 with price 20.01; prev price: 20.02
# New net worth: 1040516.1600000001
# Removed NI from current_buys for 2019-6 with price 23.49; prev price: 22.88
# New net worth: 1046064.7200000002
# Removed UDR from current_buys for 2019-6 with price 37.32; prev price: 36.89
# New net worth: 1048490.3500000002
# Added CTRA to current_buys for 2019-7 with price 18.21
# Added LULU to current_buys for 2019-7 with price 179.95
# Added UDR to current_buys for 2019-7 with price 37.39
# Removed CTRA from current_buys for 2019-8 with price 14.82; prev price: 18.21
# New net worth: 1009454.5000000002
# Removed LULU from current_buys for 2019-8 with price 185.45; prev price: 179.95
# New net worth: 1015862.0000000002
# Removed UDR from current_buys for 2019-8 with price 38.47; prev price: 37.39
# New net worth: 1021918.6400000002
# Added AJG to current_buys for 2019-9 with price 83.87
# Added IPG to current_buys for 2019-9 with price 16.49
# Added NFLX to current_buys for 2019-9 with price 289.29
# Added TSCO to current_buys for 2019-9 with price 92.79
# Removed AJG from current_buys for 2019-10 with price 82.66; prev price: 83.87
# New net worth: 1018971.0800000003
# Removed NFLX from current_buys for 2019-10 with price 269.58; prev price: 289.29
# New net worth: 1005055.8200000003
# Removed TSCO from current_buys for 2019-10 with price 83.17; prev price: 92.79
# New net worth: 983872.5800000002
# Added BG to current_buys for 2020-2 with price 45.99
# Removed BG from current_buys for 2020-3 with price 42.93; prev price: 45.99
# New net worth: 970781.9000000003
# Added APH to current_buys for 2020-9 with price 26.53
# Added CHD to current_buys for 2020-9 with price 90.99
# Added DOV to current_buys for 2020-9 with price 105.84
# Added ETSY to current_buys for 2020-9 with price 125.05
# Removed APH from current_buys for 2020-10 with price 26.35; prev price: 26.53
# New net worth: 969464.6600000003
# Removed CHD from current_buys for 2020-10 with price 88.86; prev price: 90.99
# New net worth: 964921.3700000002
# Removed DOV from current_buys for 2020-10 with price 101.77; prev price: 105.84
# New net worth: 957456.9900000002
# Removed ETSY from current_buys for 2020-10 with price 131.69; prev price: 125.05
# New net worth: 967224.4300000002
# Added ABT to current_buys for 2021-1 with price 102.04
# Added ADP to current_buys for 2021-1 with price 157.28
# Added AMD to current_buys for 2021-1 with price 92.3
# Added AMP to current_buys for 2021-1 with price 177.03
# Removed ABT from current_buys for 2021-2 with price 115.07; prev price: 102.04
# New net worth: 991916.2800000001
# Removed ADP from current_buys for 2021-2 with price 154.85; prev price: 157.28
# New net worth: 988929.8100000002
# Removed AMD from current_buys for 2021-2 with price 87.66; prev price: 92.3
# New net worth: 979209.0100000001
# Removed AMP from current_buys for 2021-2 with price 189.01; prev price: 177.03
# New net worth: 991572.3700000001
# Added BBWI to current_buys for 2021-2 with price 31.93
# Added BBY to current_buys for 2021-2 with price 93.52
# Removed BBWI from current_buys for 2021-3 with price 43.28; prev price: 31.93
# New net worth: 1062055.87
# Removed BBY from current_buys for 2021-3 with price 88.31; prev price: 93.52
# New net worth: 1051010.6700000002
# Added SWKS to current_buys for 2021-3 with price 172.62
# Added AAPL to current_buys for 2021-4 with price 120.59
# Added AMD to current_buys for 2021-4 with price 81.09
# Added APH to current_buys for 2021-4 with price 32.41
# Removed AAPL from current_buys for 2021-5 with price 129.95; prev price: 120.59
# New net worth: 1067325.1500000001
# Removed AMD from current_buys for 2021-5 with price 78.55; prev price: 81.09
# New net worth: 1060741.4700000002
# Removed APH from current_buys for 2021-5 with price 32.02; prev price: 32.41
# New net worth: 1058212.3200000003
# Removed SWKS from current_buys for 2021-5 with price 163.25; prev price: 172.62
# New net worth: 1046809.0300000003
# Added AAPL to current_buys for 2021-7 with price 134.81
# Added ARE to current_buys for 2021-7 with price 164.05
# Added DOW to current_buys for 2021-7 with price 54.69
# Added LYB to current_buys for 2021-7 with price 83.64
# Removed AAPL from current_buys for 2021-8 with price 142.91; prev price: 134.81
# New net worth: 1059388.3300000003
# Removed ARE from current_buys for 2021-8 with price 182.72; prev price: 164.05
# New net worth: 1083211.2500000002
# Removed DOW from current_buys for 2021-8 with price 52.73; prev price: 54.69
# New net worth: 1075708.3700000003
# Removed LYB from current_buys for 2021-8 with price 79.96; prev price: 83.64
# New net worth: 1066497.3300000003
# Added MAR to current_buys for 2021-9 with price 131.61
# Added STLD to current_buys for 2021-9 with price 63.91
# Added BR to current_buys for 2021-10 with price 158.14
# Added CCI to current_buys for 2021-10 with price 151.86
# Removed STLD from current_buys for 2021-10 with price 55.81; prev price: 63.91
# New net worth: 1039467.6300000004
# Removed BR from current_buys for 2021-11 with price 168.83; prev price: 158.14
# New net worth: 1053877.7500000005
# Removed CCI from current_buys for 2021-11 with price 159.32; prev price: 151.86
# New net worth: 1064351.5900000003
# Removed MAR from current_buys for 2021-11 with price 157.97; prev price: 131.61
# New net worth: 1107054.7900000003
# Added A to current_buys for 2021-12 with price 145.49
# Added ABT to current_buys for 2021-12 with price 120.37
# Added ADM to current_buys for 2021-12 with price 57.77
# Added AEP to current_buys for 2021-12 with price 72.37
# Removed A from current_buys for 2022-1 with price 153.81; prev price: 145.49
# New net worth: 1119709.5100000002
# Removed ABT from current_buys for 2022-1 with price 132.05; prev price: 120.37
# New net worth: 1141189.0300000003
# Removed ADM from current_buys for 2022-1 with price 63.44; prev price: 57.77
# New net worth: 1162916.4700000002
# Removed AEP from current_buys for 2022-1 with price 79.88; prev price: 72.37
# New net worth: 1185889.56
# Removed IPG from current_buys for 2022-1 with price 34.3; prev price: 16.49
# New net worth: 1406626.7000000002
# Added CBRE to current_buys for 2022-2 with price 101.53
# Added DOC to current_buys for 2022-2 with price 30.1
# Removed CBRE from current_buys for 2022-3 with price 95.54; prev price: 101.53
# New net worth: 1390034.4000000001
# Removed DOC from current_buys for 2022-3 with price 26.79; prev price: 30.1
# New net worth: 1359099.1400000001
# Added EL to current_buys for 2022-4 with price 265.5
# Added KIM to current_buys for 2022-4 with price 22.29
# Removed EL from current_buys for 2022-5 with price 252.17; prev price: 265.5
# New net worth: 1345462.55
# Added ALB to current_buys for 2022-7 with price 201.35
# Removed ALB from current_buys for 2022-8 with price 235.52; prev price: 201.35
# New net worth: 1391113.6700000002
# Added AAPL to current_buys for 2022-10 with price 140.89
# Added ADBE to current_buys for 2022-10 with price 285.24
# Added ADI to current_buys for 2022-10 with price 140.55
# Added AEE to current_buys for 2022-10 with price 78.2
# Removed AAPL from current_buys for 2022-11 with price 149.0; prev price: 140.89
# New net worth: 1407122.81
# Removed ADBE from current_buys for 2022-11 with price 316.02; prev price: 285.24
# New net worth: 1437133.31
# Removed ADI from current_buys for 2022-11 with price 140.14; prev price: 140.55
# New net worth: 1436321.9200000002
# Removed AEE from current_buys for 2022-11 with price 77.6; prev price: 78.2
# New net worth: 1434187.72
# Added BAX to current_buys for 2022-12 with price 50.09
# Added CAH to current_buys for 2022-12 with price 76.26
# Added CRL to current_buys for 2022-12 with price 226.2
# Added CRM to current_buys for 2022-12 with price 146.58
# Removed BAX from current_buys for 2023-1 with price 48.8; prev price: 50.09
# New net worth: 1426801.18
# Removed CAH from current_buys for 2023-1 with price 74.3; prev price: 76.26
# New net worth: 1419429.6199999999
# Removed CRL from current_buys for 2023-1 with price 218.4; prev price: 226.2
# New net worth: 1409539.22
# Removed CRM from current_buys for 2023-1 with price 134.39; prev price: 146.58
# New net worth: 1385695.58
# Added CRWD to current_buys for 2023-1 with price 103.28
# Added EA to current_buys for 2023-1 with price 121.55
# Added GE to current_buys for 2023-1 with price 52.6
# Added MPC to current_buys for 2023-1 with price 106.77
# Removed CRWD from current_buys for 2023-2 with price 110.5; prev price: 103.28
# New net worth: 1405066.84
# Removed EA from current_buys for 2023-2 with price 115.57; prev price: 121.55
# New net worth: 1391432.44
# Removed GE from current_buys for 2023-2 with price 65.27; prev price: 52.6
# New net worth: 1458178.0
# Removed MPC from current_buys for 2023-2 with price 118.37; prev price: 106.77
# New net worth: 1488280.0
# Added ABNB to current_buys for 2023-4 with price 121.46
# Added TMUS to current_buys for 2023-4 with price 145.01
# Removed ABNB from current_buys for 2023-5 with price 121.42; prev price: 121.46
# New net worth: 1488182.0
# Added ALB to current_buys for 2023-5 with price 174.84
# Removed TMUS from current_buys for 2023-5 with price 141.5; prev price: 145.01
# New net worth: 1480979.48
# Removed ALB from current_buys for 2023-6 with price 192.86; prev price: 174.84
# New net worth: 1511649.52
# Added AMZN to current_buys for 2023-7 with price 130.22
# Added BKR to current_buys for 2023-7 with price 30.63
# Added BSX to current_buys for 2023-7 with price 53.54
# Added CLX to current_buys for 2023-7 with price 153.73
# Added CMS to current_buys for 2023-7 with price 57.33
# Removed AMZN from current_buys for 2023-8 with price 131.69; prev price: 130.22
# New net worth: 1515061.39
# Removed BKR from current_buys for 2023-8 with price 34.68; prev price: 30.63
# New net worth: 1555034.8900000001
# Removed BSX from current_buys for 2023-8 with price 51.89; prev price: 53.54
# New net worth: 1545718.9900000002
# Removed CLX from current_buys for 2023-8 with price 145.46; prev price: 153.73
# New net worth: 1529460.1700000004
# Removed CMS from current_buys for 2023-8 with price 57.93; prev price: 57.33
# New net worth: 1529781.7700000005
# Removed KIM from current_buys for 2023-8 with price 19.12; prev price: 22.29
# New net worth: 1491126.7900000005
# Added ABNB to current_buys for 2023-9 with price 132.69
# Added MLM to current_buys for 2023-9 with price 455.49
# Added NVDA to current_buys for 2023-9 with price 48.49
# Added POOL to current_buys for 2023-9 with price 363.58
# Removed ABNB from current_buys for 2023-10 with price 136.56; prev price: 132.69
# New net worth: 1499822.6800000006
# Removed MLM from current_buys for 2023-10 with price 404.02; prev price: 455.49
# New net worth: 1466161.3000000007
# Removed NVDA from current_buys for 2023-10 with price 44.77; prev price: 48.49
# New net worth: 1443283.3000000007
# Removed POOL from current_buys for 2023-10 with price 344.64; prev price: 363.58
# New net worth: 1427752.5000000007
# Added CVX to current_buys for 2023-11 with price 138.03
# Added DHR to current_buys for 2023-11 with price 189.39
# Added EW to current_buys for 2023-11 with price 63.83
# Added FIS to current_buys for 2023-11 with price 48.37
# Added FMC to current_buys for 2023-11 with price 48.61
# Removed CVX from current_buys for 2023-12 with price 140.3; prev price: 138.03
# New net worth: 1432446.8600000008
# Removed DHR from current_buys for 2023-12 with price 222.77; prev price: 189.39
# New net worth: 1482750.520000001
# Removed EW from current_buys for 2023-12 with price 68.36; prev price: 63.83
# New net worth: 1503013.2100000011
# Removed FIS from current_buys for 2023-12 with price 58.79; prev price: 48.37
# New net worth: 1564522.4700000011
# Removed FMC from current_buys for 2023-12 with price 54.19; prev price: 48.61
# New net worth: 1597299.390000001
# Added AKAM to current_buys for 2024-1 with price 116.88
# Added AMD to current_buys for 2024-1 with price 138.58
# Added AMZN to current_buys for 2024-1 with price 149.93
# Added APTV to current_buys for 2024-1 with price 90.17
# Added BALL to current_buys for 2024-1 with price 56.64
# Removed AKAM from current_buys for 2024-2 with price 124.04; prev price: 116.88
# New net worth: 1616867.670000001
# Added AMCR to current_buys for 2024-2 with price 9.22
# Removed AMD from current_buys for 2024-2 with price 170.48; prev price: 138.58
# New net worth: 1690397.1700000009
# Added APA to current_buys for 2024-2 with price 30.32
# Added APD to current_buys for 2024-2 with price 255.85
# Removed APTV from current_buys for 2024-2 with price 83.5; prev price: 90.17
# New net worth: 1666772.0300000007
# Added AVB to current_buys for 2024-2 with price 175.08
# Removed AMCR from current_buys for 2024-3 with price 8.98; prev price: 9.22
# New net worth: 1658354.7500000007
# Removed AMZN from current_buys for 2024-3 with price 178.22; prev price: 149.93
# New net worth: 1718612.4500000007
# Removed APA from current_buys for 2024-3 with price 29.94; prev price: 30.32
# New net worth: 1714375.4500000007
# Removed APD from current_buys for 2024-3 with price 232.62; prev price: 255.85
# New net worth: 1707963.9700000007
# Added ATO to current_buys for 2024-3 with price 111.24
# Removed AVB from current_buys for 2024-3 with price 175.07; prev price: 175.08
# New net worth: 1707947.0700000008
# Added AWK to current_buys for 2024-3 with price 118.36
# Removed BALL from current_buys for 2024-3 with price 64.1; prev price: 56.64
# New net worth: 1750021.4700000007
# Added CNP to current_buys for 2024-3 with price 27.05
# Added ED to current_buys for 2024-3 with price 85.56
# Added EXC to current_buys for 2024-3 with price 34.78
# Removed ATO from current_buys for 2024-4 with price 116.29; prev price: 111.24
# New net worth: 1765524.9700000007
# Removed AWK from current_buys for 2024-4 with price 118.97; prev price: 118.36
# New net worth: 1767285.4300000006
# Removed CNP from current_buys for 2024-4 with price 28.01; prev price: 27.05
# New net worth: 1779706.8700000006
# Removed ED from current_buys for 2024-4 with price 88.83; prev price: 85.56
# New net worth: 1793081.1700000006
# Removed EXC from current_buys for 2024-4 with price 36.48; prev price: 34.78
# New net worth: 1810188.2700000007
# Added DHI to current_buys for 2024-5 with price 142.24
# Added F to current_buys for 2024-5 with price 11.87
# Added LLY to current_buys for 2024-5 with price 774.39
# Added PODD to current_buys for 2024-5 with price 170.27
# Added TTWO to current_buys for 2024-5 with price 142.74
# Removed DHI from current_buys
# Removed F from current_buys
# Removed LLY from current_buys
# Removed PODD from current_buys
# Removed TTWO from current_buys
# 1810188.2700000005
